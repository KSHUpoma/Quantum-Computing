# %% [markdown]
# #  Complexity of Algorithms
#
# ---
#
#
# **Description**
#
# Today, we will work with two of the most famous classical search algorithms: linear and binary search. We will implement and analyze their performance.

# %%
# @title
# Importing other python libraries
import random
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %% [markdown]
# # Part 1: Linear Search
#
# ---
#
#
# In this section, we will implement and analyze the linear search algorithm.

# %% [markdown]
# # Problem #1.1
# **Together**, let's run the code below to implement linear search for a list of numbers. We will use the following variables:
#
# * list_items: A list of numbers from 0 to 49 that we will search through.
# * marked_item: A randomly selected number from the list that we will search for.
# * number_queries: A count of how many times we need to query the list to find the marked item.

# %%
list_items = range(50)

marked_item = random.choice(list_items)
number_queries = 0
for item in list_items:

    number_queries = number_queries + 1

    if item == marked_item:
        print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break
# Out:
# 3 has been found in 4 queries.

# %% [markdown]
# # Problem #1.2
#
# ---
#
#
# Together, let's complete the code below to run our linear search many times to find the worst number of queries. We will use the following additional variables:
#
# * number_trials: The number of times to repeat the linear search.
# * worst_query: The most number of queries we had to make across all trials.

# %%
number_trials = 10
worst_query = 0
list_items = range(50)

for i in range(number_trials):

  marked_item = random.choice(list_items)
  number_queries = 0
  for item in list_items:

      number_queries = number_queries + 1

      if item == marked_item:
        print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break

  worst_query = max(worst_query, number_queries)

print("Worst number of queries: " + str(worst_query))
# Out:
# 45 has been found in 46 queries.
# 37 has been found in 38 queries.
# 24 has been found in 25 queries.
# 15 has been found in 16 queries.
# 25 has been found in 26 queries.
# 43 has been found in 44 queries.
# 35 has been found in 36 queries.
# 36 has been found in 37 queries.
# 33 has been found in 34 queries.
# 31 has been found in 32 queries.
# Worst number of queries: 46

# %% [markdown]
# # Problem #1.3
# Together, let's put this code into a function called linear_search such that it:
#
# * Takes n as input parameters.
# * Runs the code we wrote in Exercise #2 such that there are n items in list_items.
# * Returns the worst number of queries instead of printing it.

# %%
def linear_search(n):

  number_trials = 10
  worst_query = 0
  list_items = range(n)

  for i in range(number_trials):

    marked_item = random.choice(list_items)
    number_queries = 0
    for item in list_items:

      number_queries = number_queries + 1

      if item == marked_item:
        #print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break

    worst_query = max(worst_query, number_queries)

  return worst_query

# %% [markdown]
# # Problem #1.4
#
# ---
#
#
# Together, let's graph the worst number of queries for list sizes from 100 to 10000.

# %%
linear_queries = []
ns = range(100, 10000, 100)
for n in ns:
  linear_queries += [linear_search(n)]

plt.scatter(ns, linear_queries, label = "linear")

plt.xlabel("n")
plt.ylabel("Worst Number of Queries")
plt.title("Linear Search Worst Number of Queries with Increasing List Size")
plt.legend()

plt.plot()
# Out:
# []

# %% [markdown]
# # Part 2: Binary Search
#
# ---
#
#
# In this section, we will implement and analyze the binary search algorithm. We will also visually compare it to the linear search algorithm we implemented above.

# %% [markdown]
# # Problem #2.1
# **Together**, let's complete the code below to implement binary search for a list of numbers. We will use the following variables:
#
# * list_items: A list of numbers from 0 to 49 that we will search through.
# * marked_item: A randomly selected number from the list that we will search for.
# * number_queries: A count of how many times we need to query the list to find the marked item.

# %%
list_items = range(50)
marked_item = random.choice(list_items)

left = 0
right = len(list_items) - 1

number_queries = 0
for item in list_items:

  number_queries = number_queries + 1

  middle = int((left + right)/2)
  if list_items[middle] > marked_item:
    right = middle
  elif list_items[middle] < marked_item:
    left = middle
    if left == len(list_items) - 2:
        left = left + 1
  else:
    print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
    break
# Out:
# 5 has been found in 6 queries.

# %% [markdown]
# # Problem #2.2
#
# ---
#
#
# **Independently**, complete the code below to run our binary search many times to find the worst number of queries. You will use the following additional variables:
#
# * number_trials: The number of times to repeat the binary search.
# * worst_query: The most number of queries we had to make across all trials.

# %%
number_trials = 10
worst_query = 0
list_items = range(50)

for i in range(number_trials):

  marked_item = random.choice(list_items)

  left = 0
  right = len(list_items) - 1

  number_queries = 0
  for item in list_items:

    number_queries = number_queries + 1

    middle = int((left + right)/2)
    if list_items[middle] > marked_item:
      right = middle
    elif list_items[middle] < marked_item:
      left = middle
      if left == len(list_items) - 2:
         left = left + 1
    else:
      print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
      break

  worst_query = max(worst_query, number_queries)

print("Worst number of queries: " + str(worst_query))
# Out:
# 18 has been found in 3 queries.
# 23 has been found in 6 queries.
# 1 has been found in 5 queries.
# 9 has been found in 4 queries.
# 40 has been found in 5 queries.
# 48 has been found in 6 queries.
# 15 has been found in 4 queries.
# 46 has been found in 6 queries.
# 36 has been found in 2 queries.
# 8 has been found in 6 queries.
# Worst number of queries: 6

# %% [markdown]
# # Problem #2.3
#
# ---
#
#
# **Independently**, put this code into a function called binary_search such that it:
#
# * Takes n as input parameters.
# * Runs the code we wrote in Exercise #2 such that there are n items in list_items.
# * Returns the worst number of queries instead of printing it.

# %%
def binary_search(n):

  number_trials = 10
  worst_query = 0
  list_items = range(n)

  for i in range(number_trials):

    marked_item = random.choice(list_items)

    left = 0
    right = len(list_items) - 1

    number_queries = 0
    for item in list_items:

      number_queries = number_queries + 1

      middle = int((left + right)/2)
      if list_items[middle] > marked_item:
        right = middle
      elif list_items[middle] < marked_item:
        left = middle
        if left == len(list_items) - 2:
          left = left + 1
      else:
        print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break

    worst_query = max(worst_query, number_queries)

  return worst_query

# %% [markdown]
# # Problem #2.4
#
# ---
#
#
# Together, graph the worst number of queries for list sizes from 100 to 10000.

# %%
# Importing  python libraries
import random
import matplotlib.pyplot as plt



binary_queries = []
ns = range(100, 10000, 100)
for n in ns:
  binary_queries += [binary_search(n)]

plt.scatter(ns, binary_queries, label = "binary")

plt.xlabel("n")
plt.ylabel("Worst Number of Queries")
plt.title("Binary Search Worst Number of Queries with Increasing List Size")
plt.legend()

plt.plot()
# Out:
# 46 has been found in 7 queries.
# 25 has been found in 6 queries.
# 38 has been found in 7 queries.
# 46 has been found in 7 queries.
# 3 has been found in 5 queries.
# 48 has been found in 7 queries.
# 2 has been found in 7 queries.
# 84 has been found in 6 queries.
# 88 has been found in 7 queries.
# 92 has been found in 4 queries.
# 87 has been found in 7 queries.
# 147 has been found in 7 queries.
# 52 has been found in 6 queries.
# 110 has been found in 8 queries.
# 166 has been found in 8 queries.
# 22 has been found in 7 queries.
# 161 has been found in 4 queries.
# 194 has been found in 8 queries.
# 17 has been found in 8 queries.
# 197 has been found in 7 queries.
# 234 has been found in 8 queries.
# 289 has been found in 5 queries.
# 267 has been found in 7 queries.
# 242 has been found in 4 queries.
# 55 has been found in 4 queries.
# 166 has been found in 9 queries.
# 267 has been found in 7 queries.
# 133 has been found in 8 queries.
# 242 has been found in 4 queries.
# 232 has been found in 9 queries.
# 319 has been found in 9 queries.
# 247 has been found in 8 queries.
# 214 has been found in 7 queries.
# 149 has been found in 3 queries.
# 186 has been found in 5 queries.
# 283 has been found in 7 queries.
# 132 has been found in 9 queries.
# 119 has been found in 9 queries.
# 347 has been found in 8 queries.
# 209 has been found in 8 queries.
# 276 has been found in 7 queries.
# 185 has been found in 9 queries.
# 137 has been found in 8 queries.
# 414 has been found in 8 queries.
# 325 has been found in 9 queries.
# 15 has been found in 5 queries.
# 311 has been found in 3 queries.
# 258 has been found in 8 queries.
# 294 has been found in 9 queries.
# 112 has been found in 7 queries.
# 65 has been found in 9 queries.
# 555 has been found in 10 queries.
# 5 has been found in 9 queries.
# 466 has been found in 10 queries.
# 460 has been found in 8 queries.
# 588 has been found in 10 queries.
# 376 has been found in 8 queries.
# 324 has been found in 9 queries.
# 349 has been found in 10 queries.
# 143 has been found in 10 queries.
# 196 has been found in 9 queries.
# 515 has been found in 8 queries.
# 274 has been found in 8 queries.
# 341 has been found in 9 queries.
# 543 has been found in 9 queries.
# 198 has been found in 9 queries.
# 420 has been found in 9 queries.
# 152 has been found in 5 queries.
# 458 has been found in 5 queries.
# 268 has been found in 10 queries.
# 320 has been found in 8 queries.
# 299 has been found in 3 queries.
# 274 has been found in 5 queries.
# 668 has been found in 9 queries.
# 17 has been found in 10 queries.
# 98 has been found in 10 queries.
# 690 has been found in 9 queries.
# 504 has been found in 10 queries.
# 339 has been found in 8 queries.
# 453 has been found in 9 queries.
# 183 has been found in 9 queries.
# 313 has been found in 9 queries.
# 723 has been found in 7 queries.
# 216 has been found in 10 queries.
# 112 has been found in 3 queries.
# 750 has been found in 10 queries.
# 448 has been found in 10 queries.
# 231 has been found in 7 queries.
# 393 has been found in 9 queries.
# 276 has been found in 8 queries.
# 200 has been found in 10 queries.
# 860 has been found in 9 queries.
# 58 has been found in 8 queries.
# 388 has been found in 10 queries.
# 522 has been found in 7 queries.
# 584 has been found in 7 queries.
# 993 has been found in 9 queries.
# 832 has been found in 9 queries.
# 875 has been found in 9 queries.
# 686 has been found in 4 queries.
# 433 has been found in 10 queries.
# 508 has been found in 10 queries.
# 182 has been found in 10 queries.
# 304 has been found in 10 queries.
# 99 has been found in 9 queries.
# 255 has been found in 11 queries.
# 324 has been found in 11 queries.
# 178 has been found in 10 queries.
# 747 has been found in 10 queries.
# 1015 has been found in 10 queries.
# 388 has been found in 10 queries.
# 872 has been found in 9 queries.
# 1043 has been found in 11 queries.
# 50 has been found in 8 queries.
# 1051 has been found in 9 queries.
# 401 has been found in 7 queries.
# 930 has been found in 11 queries.
# 399 has been found in 10 queries.
# 916 has been found in 11 queries.
# 1139 has been found in 9 queries.
# 633 has been found in 8 queries.
# 860 has been found in 11 queries.
# 629 has been found in 10 queries.
# 346 has been found in 9 queries.
# 1138 has been found in 9 queries.
# 295 has been found in 9 queries.
# 879 has been found in 10 queries.
# 49 has been found in 11 queries.
# 295 has been found in 9 queries.
# 1213 has been found in 11 queries.
# 189 has been found in 8 queries.
# 78 has been found in 9 queries.
# 1085 has been found in 11 queries.
# 136 has been found in 10 queries.
# 1092 has been found in 5 queries.
# 1266 has been found in 11 queries.
# 903 has been found in 9 queries.
# 1372 has been found in 10 queries.
# 177 has been found in 10 queries.
# 339 has been found in 10 queries.
# 887 has been found in 10 queries.
# 1364 has been found in 10 queries.
# 972 has been found in 10 queries.
# 1195 has been found in 11 queries.
# 1458 has been found in 10 queries.
# 168 has been found in 11 queries.
# 1323 has been found in 10 queries.
# 385 has been found in 7 queries.
# 920 has been found in 11 queries.
# 879 has been found in 11 queries.
# 373 has been found in 11 queries.
# 693 has been found in 10 queries.
# 1036 has been found in 7 queries.
# 1305 has been found in 8 queries.
# 368 has been found in 10 queries.
# 1546 has been found in 11 queries.
# 36 has been found in 7 queries.
# 187 has been found in 10 queries.
# 712 has been found in 10 queries.
# 1251 has been found in 11 queries.
# 878 has been found in 9 queries.
# 1241 has been found in 10 queries.
# 212 has been found in 3 queries.
# 1490 has been found in 10 queries.
# 1140 has been found in 6 queries.
# 410 has been found in 7 queries.
# 1517 has been found in 11 queries.
# 1179 has been found in 11 queries.
# 1465 has been found in 8 queries.
# 1450 has been found in 10 queries.
# 977 has been found in 10 queries.
# 636 has been found in 10 queries.
# 834 has been found in 11 queries.
# 1584 has been found in 9 queries.
# 691 has been found in 9 queries.
# 1477 has been found in 11 queries.
# 810 has been found in 9 queries.
# 1767 has been found in 11 queries.
# 680 has been found in 11 queries.
# 76 has been found in 11 queries.
# 587 has been found in 11 queries.
# 1706 has been found in 10 queries.
# 1771 has been found in 11 queries.
# 781 has been found in 9 queries.
# 1751 has been found in 10 queries.
# 116 has been found in 10 queries.
# 1287 has been found in 11 queries.
# 1454 has been found in 10 queries.
# 33 has been found in 11 queries.
# 99 has been found in 9 queries.
# 367 has been found in 11 queries.
# 313 has been found in 11 queries.
# 1342 has been found in 6 queries.
# 1299 has been found in 9 queries.
# 1547 has been found in 10 queries.
# 1701 has been found in 7 queries.
# 284 has been found in 11 queries.
# 1978 has been found in 11 queries.
# 1355 has been found in 11 queries.
# 1598 has been found in 10 queries.
# 32 has been found in 6 queries.
# 1689 has been found in 11 queries.
# 805 has been found in 11 queries.
# 1307 has been found in 11 queries.
# 1378 has been found in 10 queries.
# 39 has been found in 11 queries.
# 532 has been found in 8 queries.
# 754 has been found in 11 queries.
# 658 has been found in 11 queries.
# 158 has been found in 11 queries.
# 206 has been found in 11 queries.
# 929 has been found in 11 queries.
# 453 has been found in 8 queries.
# 1163 has been found in 11 queries.
# 688 has been found in 10 queries.
# 526 has been found in 9 queries.
# 241 has been found in 10 queries.
# 1225 has been found in 11 queries.
# 2103 has been found in 8 queries.
# 311 has been found in 11 queries.
# 541 has been found in 11 queries.
# 2095 has been found in 11 queries.
# 2167 has been found in 11 queries.
# 1050 has been found in 8 queries.
# 347 has been found in 11 queries.
# 60 has been found in 11 queries.
# 89 has been found in 7 queries.
# 1294 has been found in 10 queries.
# 1712 has been found in 10 queries.
# 1893 has been found in 12 queries.
# 735 has been found in 11 queries.
# 405 has been found in 12 queries.
# 972 has been found in 11 queries.
# 2170 has been found in 11 queries.
# 1159 has been found in 11 queries.
# 1964 has been found in 10 queries.
# 1380 has been found in 12 queries.
# 735 has been found in 11 queries.
# 1149 has been found in 11 queries.
# 2349 has been found in 11 queries.
# 1077 has been found in 9 queries.
# 182 has been found in 10 queries.
# 1421 has been found in 10 queries.
# 2154 has been found in 11 queries.
# 1328 has been found in 11 queries.
# 1629 has been found in 8 queries.
# 955 has been found in 7 queries.
# 2423 has been found in 11 queries.
# 1974 has been found in 11 queries.
# 1795 has been found in 5 queries.
# 850 has been found in 12 queries.
# 1223 has been found in 11 queries.
# 1969 has been found in 7 queries.
# 1459 has been found in 11 queries.
# 1149 has been found in 11 queries.
# 2238 has been found in 9 queries.
# 1420 has been found in 6 queries.
# 2200 has been found in 11 queries.
# 1676 has been found in 10 queries.
# 695 has been found in 11 queries.
# 2515 has been found in 12 queries.
# 1522 has been found in 9 queries.
# 1616 has been found in 9 queries.
# 1395 has been found in 12 queries.
# 2018 has been found in 9 queries.
# 2459 has been found in 12 queries.
# 826 has been found in 9 queries.
# 2375 has been found in 12 queries.
# 1774 has been found in 12 queries.
# 1847 has been found in 11 queries.
# 647 has been found in 11 queries.
# 2502 has been found in 12 queries.
# 1131 has been found in 11 queries.
# 15 has been found in 9 queries.
# 2555 has been found in 10 queries.
# 1309 has been found in 11 queries.
# 302 has been found in 10 queries.
# 1563 has been found in 8 queries.
# 1522 has been found in 11 queries.
# 146 has been found in 9 queries.
# 2413 has been found in 10 queries.
# 1206 has been found in 10 queries.
# 2551 has been found in 12 queries.
# 439 has been found in 12 queries.
# 496 has been found in 12 queries.
# 2814 has been found in 11 queries.
# 1893 has been found in 11 queries.
# 577 has been found in 11 queries.
# 502 has been found in 9 queries.
# 2261 has been found in 10 queries.
# 2756 has been found in 11 queries.
# 726 has been found in 11 queries.
# 2484 has been found in 11 queries.
# 2521 has been found in 10 queries.
# 1757 has been found in 11 queries.
# 2276 has been found in 12 queries.
# 1900 has been found in 11 queries.
# 1649 has been found in 12 queries.
# 195 has been found in 10 queries.
# 1243 has been found in 10 queries.
# 2265 has been found in 12 queries.
# 203 has been found in 11 queries.
# 2491 has been found in 12 queries.
# 1297 has been found in 10 queries.
# 461 has been found in 12 queries.
# 2515 has been found in 11 queries.
# 772 has been found in 11 queries.
# 2658 has been found in 12 queries.
# 2490 has been found in 11 queries.
# 2579 has been found in 12 queries.
# 816 has been found in 12 queries.
# 3090 has been found in 11 queries.
# 413 has been found in 12 queries.
# 2979 has been found in 12 queries.
# 1488 has been found in 12 queries.
# 3141 has been found in 12 queries.
# 3073 has been found in 12 queries.
# 1282 has been found in 12 queries.
# 2967 has been found in 9 queries.
# 3142 has been found in 9 queries.
# 1554 has been found in 10 queries.
# 349 has been found in 12 queries.
# 2192 has been found in 10 queries.
# 137 has been found in 10 queries.
# 108 has been found in 12 queries.
# 391 has been found in 12 queries.
# 3205 has been found in 12 queries.
# 1181 has been found in 12 queries.
# 3 has been found in 10 queries.
# 2795 has been found in 8 queries.
# 2465 has been found in 12 queries.
# 990 has been found in 10 queries.
# 1301 has been found in 11 queries.
# 2813 has been found in 12 queries.
# 3091 has been found in 11 queries.
# 1309 has been found in 10 queries.
# 1132 has been found in 12 queries.
# 467 has been found in 12 queries.
# 501 has been found in 11 queries.
# 322 has been found in 11 queries.
# 2240 has been found in 6 queries.
# 134 has been found in 11 queries.
# 1759 has been found in 12 queries.
# 2384 has been found in 9 queries.
# 872 has been found in 11 queries.
# 3488 has been found in 10 queries.
# 1486 has been found in 11 queries.
# 2293 has been found in 11 queries.
# 634 has been found in 9 queries.
# 808 has been found in 10 queries.
# 2252 has been found in 10 queries.
# 106 has been found in 11 queries.
# 477 has been found in 7 queries.
# 766 has been found in 11 queries.
# 3040 has been found in 12 queries.
# 3129 has been found in 12 queries.
# 488 has been found in 12 queries.
# 106 has been found in 11 queries.
# 3508 has been found in 11 queries.
# 1679 has been found in 9 queries.
# 2906 has been found in 10 queries.
# 2158 has been found in 9 queries.
# 571 has been found in 11 queries.
# 508 has been found in 12 queries.
# 1205 has been found in 12 queries.
# 537 has been found in 12 queries.
# 3675 has been found in 11 queries.
# 185 has been found in 11 queries.
# 81 has been found in 12 queries.
# 2474 has been found in 11 queries.
# 1950 has been found in 9 queries.
# 172 has been found in 12 queries.
# 3406 has been found in 11 queries.
# 462 has been found in 10 queries.
# 3228 has been found in 11 queries.
# 3443 has been found in 11 queries.
# 2878 has been found in 7 queries.
# 852 has been found in 12 queries.
# 3108 has been found in 12 queries.
# 1453 has been found in 7 queries.
# 2086 has been found in 11 queries.
# 631 has been found in 12 queries.
# 3728 has been found in 12 queries.
# 3030 has been found in 12 queries.
# 2814 has been found in 12 queries.
# 3728 has been found in 12 queries.
# 3261 has been found in 10 queries.
# 3346 has been found in 10 queries.
# 3207 has been found in 12 queries.
# 3267 has been found in 11 queries.
# 808 has been found in 12 queries.
# 3131 has been found in 9 queries.
# 1828 has been found in 11 queries.
# 3682 has been found in 10 queries.
# 3703 has been found in 11 queries.
# 942 has been found in 12 queries.
# 376 has been found in 12 queries.
# 3351 has been found in 12 queries.
# 1893 has been found in 10 queries.
# 1636 has been found in 12 queries.
# 1156 has been found in 10 queries.
# 2854 has been found in 12 queries.
# 2245 has been found in 10 queries.
# 1157 has been found in 12 queries.
# 2133 has been found in 10 queries.
# 2780 has been found in 12 queries.
# 2750 has been found in 12 queries.
# 2173 has been found in 10 queries.
# 25 has been found in 12 queries.
# 3831 has been found in 12 queries.
# 830 has been found in 10 queries.
# 3251 has been found in 10 queries.
# 2745 has been found in 12 queries.
# 2895 has been found in 12 queries.
# 2656 has been found in 7 queries.
# 178 has been found in 12 queries.
# 1484 has been found in 12 queries.
# 2042 has been found in 12 queries.
# 729 has been found in 12 queries.
# 355 has been found in 10 queries.
# 1029 has been found in 11 queries.
# 3170 has been found in 11 queries.
# 1843 has been found in 11 queries.
# 1099 has been found in 12 queries.
# 1047 has been found in 12 queries.
# 2457 has been found in 12 queries.
# 888 has been found in 8 queries.
# 1117 has been found in 11 queries.
# 2016 has been found in 11 queries.
# 3074 has been found in 11 queries.
# 3360 has been found in 11 queries.
# 3882 has been found in 13 queries.
# 392 has been found in 13 queries.
# 1290 has been found in 12 queries.
# 603 has been found in 12 queries.
# 2134 has been found in 10 queries.
# 598 has been found in 12 queries.
# 3556 has been found in 8 queries.
# 4087 has been found in 12 queries.
# 574 has been found in 9 queries.
# 2662 has been found in 12 queries.
# 142 has been found in 11 queries.
# 2772 has been found in 11 queries.
# 3018 has been found in 11 queries.
# 2551 has been found in 10 queries.
# 3207 has been found in 12 queries.
# 824 has been found in 13 queries.
# 4283 has been found in 12 queries.
# 2623 has been found in 11 queries.
# 2547 has been found in 8 queries.
# 117 has been found in 12 queries.
# 4292 has been found in 13 queries.
# 2356 has been found in 10 queries.
# 4571 has been found in 13 queries.
# 1374 has been found in 12 queries.
# 3642 has been found in 12 queries.
# 414 has been found in 11 queries.
# 251 has been found in 7 queries.
# 2439 has been found in 11 queries.
# 949 has been found in 12 queries.
# 1815 has been found in 8 queries.
# 2494 has been found in 13 queries.
# 1046 has been found in 12 queries.
# 2694 has been found in 12 queries.
# 4004 has been found in 10 queries.
# 1974 has been found in 12 queries.
# 2881 has been found in 12 queries.
# 4600 has been found in 12 queries.
# 1166 has been found in 11 queries.
# 2110 has been found in 12 queries.
# 2369 has been found in 13 queries.
# 2966 has been found in 12 queries.
# 3148 has been found in 13 queries.
# 3850 has been found in 13 queries.
# 1190 has been found in 12 queries.
# 4260 has been found in 12 queries.
# 541 has been found in 13 queries.
# 2333 has been found in 9 queries.
# 1205 has been found in 11 queries.
# 1772 has been found in 11 queries.
# 1826 has been found in 9 queries.
# 1011 has been found in 12 queries.
# 4565 has been found in 12 queries.
# 1529 has been found in 13 queries.
# 2908 has been found in 5 queries.
# 4433 has been found in 13 queries.
# 1424 has been found in 9 queries.
# 3129 has been found in 11 queries.
# 3879 has been found in 10 queries.
# 2744 has been found in 13 queries.
# 1307 has been found in 8 queries.
# 2358 has been found in 11 queries.
# 4654 has been found in 12 queries.
# 3730 has been found in 12 queries.
# 1874 has been found in 3 queries.
# 3738 has been found in 13 queries.
# 3101 has been found in 11 queries.
# 900 has been found in 12 queries.
# 3698 has been found in 13 queries.
# 2387 has been found in 11 queries.
# 3223 has been found in 12 queries.
# 4112 has been found in 9 queries.
# 2494 has been found in 10 queries.
# 1822 has been found in 12 queries.
# 1094 has been found in 8 queries.
# 2075 has been found in 10 queries.
# 783 has been found in 11 queries.
# 4093 has been found in 12 queries.
# 4665 has been found in 10 queries.
# 2642 has been found in 13 queries.
# 850 has been found in 13 queries.
# 184 has been found in 11 queries.
# 3897 has been found in 12 queries.
# 3722 has been found in 11 queries.
# 2093 has been found in 12 queries.
# 3847 has been found in 9 queries.
# 3373 has been found in 12 queries.
# 4777 has been found in 12 queries.
# 2627 has been found in 12 queries.
# 533 has been found in 11 queries.
# 1462 has been found in 10 queries.
# 3651 has been found in 13 queries.
# 884 has been found in 12 queries.
# 343 has been found in 11 queries.
# 1113 has been found in 11 queries.
# 2317 has been found in 4 queries.
# 1742 has been found in 10 queries.
# 3272 has been found in 12 queries.
# 3017 has been found in 13 queries.
# 3670 has been found in 12 queries.
# 687 has been found in 12 queries.
# 29 has been found in 12 queries.
# 1423 has been found in 12 queries.
# 696 has been found in 12 queries.
# 3091 has been found in 12 queries.
# 1674 has been found in 13 queries.
# 1668 has been found in 13 queries.
# 4027 has been found in 8 queries.
# 3673 has been found in 10 queries.
# 1558 has been found in 13 queries.
# 4063 has been found in 13 queries.
# 817 has been found in 11 queries.
# 3865 has been found in 13 queries.
# 895 has been found in 10 queries.
# 285 has been found in 13 queries.
# 3295 has been found in 13 queries.
# 901 has been found in 7 queries.
# 5083 has been found in 13 queries.
# 2196 has been found in 12 queries.
# 473 has been found in 12 queries.
# 2520 has been found in 12 queries.
# 4125 has been found in 12 queries.
# 3218 has been found in 13 queries.
# 2142 has been found in 7 queries.
# 4182 has been found in 10 queries.
# 813 has been found in 10 queries.
# 1898 has been found in 13 queries.
# 4372 has been found in 12 queries.
# 353 has been found in 13 queries.
# 727 has been found in 13 queries.
# 1291 has been found in 12 queries.
# 891 has been found in 12 queries.
# 5243 has been found in 13 queries.
# 4962 has been found in 13 queries.
# 364 has been found in 11 queries.
# 2019 has been found in 12 queries.
# 3285 has been found in 11 queries.
# 4877 has been found in 12 queries.
# 3285 has been found in 11 queries.
# 3962 has been found in 12 queries.
# 386 has been found in 11 queries.
# 1933 has been found in 13 queries.
# 776 has been found in 13 queries.
# 765 has been found in 13 queries.
# 627 has been found in 10 queries.
# 184 has been found in 12 queries.
# 2570 has been found in 12 queries.
# 3623 has been found in 13 queries.
# 1712 has been found in 12 queries.
# 3892 has been found in 11 queries.
# 896 has been found in 12 queries.
# 340 has been found in 12 queries.
# 5096 has been found in 10 queries.
# 4640 has been found in 12 queries.
# 4860 has been found in 13 queries.
# 1274 has been found in 11 queries.
# 4605 has been found in 11 queries.
# 3635 has been found in 13 queries.
# 5488 has been found in 10 queries.
# 3042 has been found in 12 queries.
# 1830 has been found in 12 queries.
# 152 has been found in 12 queries.
# 2483 has been found in 7 queries.
# 1891 has been found in 10 queries.
# 4438 has been found in 12 queries.
# 4887 has been found in 13 queries.
# 3115 has been found in 8 queries.
# 3366 has been found in 12 queries.
# 4760 has been found in 12 queries.
# 5864 has been found in 12 queries.
# 5826 has been found in 13 queries.
# 962 has been found in 13 queries.
# 2673 has been found in 12 queries.
# 240 has been found in 11 queries.
# 3845 has been found in 13 queries.
# 5827 has been found in 11 queries.
# 4761 has been found in 11 queries.
# 5306 has been found in 10 queries.
# 1073 has been found in 13 queries.
# 3141 has been found in 11 queries.
# 2541 has been found in 8 queries.
# 1299 has been found in 13 queries.
# 5659 has been found in 10 queries.
# 4578 has been found in 13 queries.
# 3455 has been found in 10 queries.
# 718 has been found in 13 queries.
# 3214 has been found in 12 queries.
# 4247 has been found in 13 queries.
# 4909 has been found in 12 queries.
# 4486 has been found in 12 queries.
# 4984 has been found in 11 queries.
# 428 has been found in 13 queries.
# 2889 has been found in 9 queries.
# 5912 has been found in 12 queries.
# 1527 has been found in 11 queries.
# 3870 has been found in 11 queries.
# 878 has been found in 10 queries.
# 3278 has been found in 12 queries.
# 1194 has been found in 13 queries.
# 1429 has been found in 11 queries.
# 5665 has been found in 12 queries.
# 4190 has been found in 12 queries.
# 53 has been found in 12 queries.
# 4586 has been found in 9 queries.
# 5141 has been found in 13 queries.
# 3851 has been found in 13 queries.
# 5157 has been found in 13 queries.
# 6248 has been found in 13 queries.
# 5402 has been found in 11 queries.
# 2946 has been found in 13 queries.
# 1161 has been found in 12 queries.
# 3131 has been found in 13 queries.
# 6080 has been found in 12 queries.
# 2242 has been found in 11 queries.
# 1011 has been found in 11 queries.
# 1905 has been found in 11 queries.
# 1863 has been found in 13 queries.
# 1581 has been found in 13 queries.
# 4619 has been found in 7 queries.
# 1303 has been found in 13 queries.
# 2248 has been found in 12 queries.
# 6480 has been found in 12 queries.
# 2376 has been found in 10 queries.
# 2305 has been found in 9 queries.
# 3775 has been found in 9 queries.
# 6212 has been found in 12 queries.
# 4991 has been found in 12 queries.
# 3298 has been found in 13 queries.
# 5886 has been found in 11 queries.
# 3821 has been found in 12 queries.
# 6239 has been found in 13 queries.
# 689 has been found in 13 queries.
# 6208 has been found in 12 queries.
# 182 has been found in 8 queries.
# 5059 has been found in 11 queries.
# 2136 has been found in 13 queries.
# 3212 has been found in 13 queries.
# 6382 has been found in 12 queries.
# 2930 has been found in 4 queries.
# 4460 has been found in 9 queries.
# 327 has been found in 11 queries.
# 2650 has been found in 13 queries.
# 887 has been found in 13 queries.
# 4060 has been found in 12 queries.
# 6530 has been found in 13 queries.
# 6388 has been found in 12 queries.
# 5368 has been found in 12 queries.
# 6180 has been found in 10 queries.
# 5316 has been found in 13 queries.
# 345 has been found in 12 queries.
# 4275 has been found in 12 queries.
# 3383 has been found in 13 queries.
# 4314 has been found in 11 queries.
# 4315 has been found in 12 queries.
# 6640 has been found in 12 queries.
# 1238 has been found in 13 queries.
# 2630 has been found in 12 queries.
# 63 has been found in 13 queries.
# 2434 has been found in 13 queries.
# 1100 has been found in 11 queries.
# 3104 has been found in 11 queries.
# 4719 has been found in 12 queries.
# 1762 has been found in 9 queries.
# 3947 has been found in 12 queries.
# 4201 has been found in 13 queries.
# 3855 has been found in 13 queries.
# 6738 has been found in 9 queries.
# 6111 has been found in 12 queries.
# 251 has been found in 10 queries.
# 836 has been found in 13 queries.
# 1510 has been found in 9 queries.
# 3165 has been found in 12 queries.
# 5806 has been found in 12 queries.
# 2334 has been found in 10 queries.
# 1520 has been found in 11 queries.
# 6968 has been found in 12 queries.
# 3996 has been found in 12 queries.
# 1104 has been found in 11 queries.
# 2137 has been found in 13 queries.
# 4898 has been found in 12 queries.
# 4364 has been found in 13 queries.
# 2267 has been found in 13 queries.
# 3602 has been found in 11 queries.
# 2461 has been found in 13 queries.
# 2670 has been found in 8 queries.
# 6109 has been found in 10 queries.
# 5564 has been found in 13 queries.
# 6621 has been found in 13 queries.
# 4305 has been found in 11 queries.
# 3555 has been found in 13 queries.
# 1974 has been found in 12 queries.
# 5579 has been found in 13 queries.
# 4359 has been found in 12 queries.
# 6094 has been found in 13 queries.
# 7017 has been found in 13 queries.
# 445 has been found in 13 queries.
# 140 has been found in 12 queries.
# 3593 has been found in 13 queries.
# 3358 has been found in 13 queries.
# 5445 has been found in 8 queries.
# 713 has been found in 13 queries.
# 3877 has been found in 12 queries.
# 4598 has been found in 11 queries.
# 6323 has been found in 12 queries.
# 6465 has been found in 13 queries.
# 3695 has been found in 11 queries.
# 5759 has been found in 12 queries.
# 4663 has been found in 13 queries.
# 5851 has been found in 9 queries.
# 5667 has been found in 11 queries.
# 1276 has been found in 11 queries.
# 283 has been found in 13 queries.
# 1476 has been found in 13 queries.
# 1880 has been found in 13 queries.
# 6930 has been found in 13 queries.
# 5638 has been found in 9 queries.
# 2766 has been found in 9 queries.
# 5560 has been found in 13 queries.
# 1474 has been found in 13 queries.
# 4733 has been found in 13 queries.
# 3981 has been found in 12 queries.
# 6152 has been found in 13 queries.
# 4084 has been found in 13 queries.
# 2655 has been found in 9 queries.
# 5933 has been found in 13 queries.
# 5073 has been found in 12 queries.
# 7554 has been found in 9 queries.
# 3816 has been found in 11 queries.
# 258 has been found in 10 queries.
# 1928 has been found in 8 queries.
# 4388 has been found in 12 queries.
# 2321 has been found in 10 queries.
# 5435 has been found in 13 queries.
# 910 has been found in 12 queries.
# 317 has been found in 13 queries.
# 1985 has been found in 12 queries.
# 2304 has been found in 12 queries.
# 6060 has been found in 12 queries.
# 3933 has been found in 12 queries.
# 7258 has been found in 11 queries.
# 1347 has been found in 13 queries.
# 6614 has been found in 13 queries.
# 6512 has been found in 13 queries.
# 4968 has been found in 13 queries.
# 4796 has been found in 13 queries.
# 7393 has been found in 13 queries.
# 1526 has been found in 13 queries.
# 5005 has been found in 13 queries.
# 4904 has been found in 8 queries.
# 1220 has been found in 11 queries.
# 5918 has been found in 12 queries.
# 1125 has been found in 9 queries.
# 7891 has been found in 10 queries.
# 1209 has been found in 10 queries.
# 737 has been found in 13 queries.
# 6836 has been found in 13 queries.
# 6113 has been found in 12 queries.
# 1899 has been found in 13 queries.
# 1896 has been found in 9 queries.
# 5144 has been found in 10 queries.
# 471 has been found in 11 queries.
# 3675 has been found in 13 queries.
# 6209 has been found in 10 queries.
# 2623 has been found in 13 queries.
# 7900 has been found in 13 queries.
# 6563 has been found in 13 queries.
# 544 has been found in 13 queries.
# 4145 has been found in 12 queries.
# 1128 has been found in 13 queries.
# 973 has been found in 12 queries.
# 1095 has been found in 13 queries.
# 3553 has been found in 11 queries.
# 4424 has been found in 11 queries.
# 7584 has been found in 10 queries.
# 4702 has been found in 12 queries.
# 6094 has been found in 13 queries.
# 2668 has been found in 13 queries.
# 605 has been found in 13 queries.
# 1098 has been found in 10 queries.
# 2119 has been found in 13 queries.
# 6110 has been found in 12 queries.
# 1191 has been found in 13 queries.
# 6503 has been found in 12 queries.
# 2043 has been found in 13 queries.
# 500 has been found in 11 queries.
# 1403 has been found in 13 queries.
# 1561 has been found in 13 queries.
# 1940 has been found in 11 queries.
# 1848 has been found in 10 queries.
# 4566 has been found in 13 queries.
# 6282 has been found in 12 queries.
# 2259 has been found in 10 queries.
# 5478 has been found in 13 queries.
# 2190 has been found in 11 queries.
# 26 has been found in 12 queries.
# 988 has been found in 9 queries.
# 260 has been found in 13 queries.
# 2678 has been found in 12 queries.
# 3432 has been found in 12 queries.
# 5441 has been found in 13 queries.
# 4379 has been found in 13 queries.
# 4569 has been found in 12 queries.
# 5315 has been found in 13 queries.
# 2944 has been found in 12 queries.
# 4817 has been found in 11 queries.
# 3592 has been found in 13 queries.
# 2357 has been found in 13 queries.
# 828 has been found in 12 queries.
# 345 has been found in 12 queries.
# 2583 has been found in 13 queries.
# 4717 has been found in 11 queries.
# 8490 has been found in 10 queries.
# 4782 has been found in 12 queries.
# 3118 has been found in 14 queries.
# 1347 has been found in 11 queries.
# 577 has been found in 13 queries.
# 2275 has been found in 13 queries.
# 2736 has been found in 13 queries.
# 8204 has been found in 13 queries.
# 4234 has been found in 12 queries.
# 1490 has been found in 12 queries.
# 8200 has been found in 13 queries.
# 6633 has been found in 9 queries.
# 888 has been found in 9 queries.
# 582 has been found in 11 queries.
# 8016 has been found in 12 queries.
# 2470 has been found in 13 queries.
# 2421 has been found in 11 queries.
# 4695 has been found in 13 queries.
# 2625 has been found in 13 queries.
# 7091 has been found in 13 queries.
# 2617 has been found in 12 queries.
# 1462 has been found in 12 queries.
# 7699 has been found in 13 queries.
# 3282 has been found in 11 queries.
# 2039 has been found in 13 queries.
# 7673 has been found in 13 queries.
# 1783 has been found in 9 queries.
# 4191 has been found in 11 queries.
# 7125 has been found in 13 queries.
# 3909 has been found in 13 queries.
# 3309 has been found in 12 queries.
# 251 has been found in 11 queries.
# 2848 has been found in 12 queries.
# 6238 has been found in 13 queries.
# 1396 has been found in 13 queries.
# 6712 has been found in 13 queries.
# 4678 has been found in 11 queries.
# 484 has been found in 11 queries.
# 6286 has been found in 12 queries.
# 7450 has been found in 11 queries.
# 2339 has been found in 13 queries.
# 4824 has been found in 12 queries.
# 3929 has been found in 13 queries.
# 1957 has been found in 13 queries.
# 5755 has been found in 11 queries.
# 7511 has been found in 13 queries.
# 3141 has been found in 12 queries.
# 7796 has been found in 12 queries.
# 3666 has been found in 13 queries.
# 2297 has been found in 13 queries.
# 2536 has been found in 12 queries.
# 2650 has been found in 13 queries.
# 6048 has been found in 13 queries.
# 2123 has been found in 13 queries.
# 8896 has been found in 13 queries.
# 1990 has been found in 12 queries.
# 7807 has been found in 11 queries.
# 4333 has been found in 12 queries.
# 1085 has been found in 12 queries.
# 5125 has been found in 10 queries.
# 4951 has been found in 13 queries.
# 279 has been found in 11 queries.
# 8135 has been found in 12 queries.
# 3845 has been found in 10 queries.
# 4318 has been found in 13 queries.
# 2452 has been found in 13 queries.
# 5672 has been found in 11 queries.
# 1381 has been found in 13 queries.
# 6778 has been found in 14 queries.
# 7624 has been found in 13 queries.
# 3699 has been found in 14 queries.
# 3550 has been found in 13 queries.
# 6501 has been found in 13 queries.
# 543 has been found in 13 queries.
# 6018 has been found in 9 queries.
# 8229 has been found in 13 queries.
# 3341 has been found in 8 queries.
# 1343 has been found in 12 queries.
# 664 has been found in 13 queries.
# 6768 has been found in 11 queries.
# 2139 has been found in 13 queries.
# 6012 has been found in 12 queries.
# 1760 has been found in 14 queries.
# 6562 has been found in 13 queries.
# 3966 has been found in 10 queries.
# 5538 has been found in 9 queries.
# 573 has been found in 12 queries.
# 4172 has been found in 12 queries.
# 8626 has been found in 13 queries.
# 5985 has been found in 12 queries.
# 1237 has been found in 10 queries.
# 8114 has been found in 13 queries.
# 6089 has been found in 13 queries.
# 5490 has been found in 13 queries.
# 5323 has been found in 13 queries.
# 4261 has been found in 13 queries.
# 1682 has been found in 11 queries.
# 3539 has been found in 12 queries.
# 6197 has been found in 13 queries.
# 6073 has been found in 14 queries.
# 1282 has been found in 13 queries.
# 1981 has been found in 13 queries.
# 6959 has been found in 13 queries.
# 1413 has been found in 11 queries.
# 539 has been found in 13 queries.
# 4488 has been found in 14 queries.
# 1051 has been found in 11 queries.
# 1361 has been found in 14 queries.
# 9461 has been found in 8 queries.
# 8434 has been found in 13 queries.
# 6615 has been found in 13 queries.
# 4290 has been found in 13 queries.
# 3287 has been found in 13 queries.
# 7616 has been found in 13 queries.
# 3501 has been found in 13 queries.
# 6317 has been found in 9 queries.
# 5200 has been found in 14 queries.
# 6343 has been found in 13 queries.
# 8356 has been found in 11 queries.
# 8565 has been found in 11 queries.
# 3253 has been found in 13 queries.
# 5419 has been found in 12 queries.
# 5179 has been found in 10 queries.
# 1672 has been found in 12 queries.
# 7757 has been found in 13 queries.
# 2641 has been found in 10 queries.
# 8882 has been found in 14 queries.
# 9595 has been found in 13 queries.
# 7065 has been found in 9 queries.
# 9508 has been found in 12 queries.
# 1156 has been found in 10 queries.
# 4948 has been found in 12 queries.
# 5135 has been found in 13 queries.
# 79 has been found in 13 queries.
# 7212 has been found in 13 queries.
# 1332 has been found in 14 queries.
# 6057 has been found in 13 queries.
# 3699 has been found in 12 queries.
# 1554 has been found in 13 queries.
# 2232 has been found in 13 queries.
# 7725 has been found in 12 queries.
# 6997 has been found in 8 queries.
# 6494 has been found in 14 queries.
# 9238 has been found in 12 queries.
# 1165 has been found in 12 queries.
# 6724 has been found in 12 queries.
# 7600 has been found in 13 queries.
# 204 has been found in 13 queries.
# 4337 has been found in 13 queries.
# []

# %% [markdown]
# # Problem #2.5
#
# ---
#
#
# Together, let's graph the worst number of queries for list sizes from 100 to 10000 for both linear and binary search.

# %%
linear_queries = []
binary_queries = []
ns = range(100, 10000, 100)
for n in ns:
  linear_queries += [linear_search(n)]
  binary_queries += [binary_search(n)]

plt.scatter(ns, linear_queries, label = "linear")
plt.scatter(ns, binary_queries, label = "binary")

plt.xlabel("n")
plt.ylabel("Worst Number of Queries")
plt.title("Linear and Binary Search Worst Number of Queries with Increasing List Size")
plt.legend()

plt.plot()
# Out:
# 89 has been found in 5 queries.
# 63 has been found in 7 queries.
# 14 has been found in 7 queries.
# 8 has been found in 7 queries.
# 99 has been found in 8 queries.
# 27 has been found in 5 queries.
# 31 has been found in 6 queries.
# 25 has been found in 6 queries.
# 74 has been found in 2 queries.
# 96 has been found in 7 queries.
# 114 has been found in 6 queries.
# 98 has been found in 8 queries.
# 134 has been found in 7 queries.
# 179 has been found in 8 queries.
# 69 has been found in 8 queries.
# 69 has been found in 8 queries.
# 102 has been found in 6 queries.
# 42 has been found in 5 queries.
# 20 has been found in 8 queries.
# 47 has been found in 7 queries.
# 18 has been found in 4 queries.
# 111 has been found in 3 queries.
# 174 has been found in 8 queries.
# 35 has been found in 8 queries.
# 45 has been found in 9 queries.
# 295 has been found in 8 queries.
# 261 has been found in 3 queries.
# 162 has been found in 6 queries.
# 102 has been found in 8 queries.
# 80 has been found in 7 queries.
# 241 has been found in 9 queries.
# 268 has been found in 8 queries.
# 30 has been found in 6 queries.
# 251 has been found in 9 queries.
# 239 has been found in 7 queries.
# 105 has been found in 6 queries.
# 61 has been found in 5 queries.
# 188 has been found in 9 queries.
# 159 has been found in 8 queries.
# 87 has been found in 8 queries.
# 249 has been found in 1 queries.
# 387 has been found in 8 queries.
# 354 has been found in 7 queries.
# 80 has been found in 9 queries.
# 422 has been found in 8 queries.
# 401 has been found in 7 queries.
# 39 has been found in 9 queries.
# 248 has been found in 9 queries.
# 103 has been found in 9 queries.
# 374 has been found in 2 queries.
# 351 has been found in 9 queries.
# 413 has been found in 8 queries.
# 537 has been found in 7 queries.
# 88 has been found in 9 queries.
# 538 has been found in 9 queries.
# 539 has been found in 8 queries.
# 21 has been found in 9 queries.
# 129 has been found in 10 queries.
# 110 has been found in 10 queries.
# 80 has been found in 8 queries.
# 520 has been found in 10 queries.
# 472 has been found in 9 queries.
# 254 has been found in 10 queries.
# 490 has been found in 10 queries.
# 11 has been found in 9 queries.
# 198 has been found in 9 queries.
# 213 has been found in 10 queries.
# 402 has been found in 10 queries.
# 647 has been found in 9 queries.
# 120 has been found in 9 queries.
# 283 has been found in 8 queries.
# 258 has been found in 8 queries.
# 167 has been found in 7 queries.
# 368 has been found in 9 queries.
# 95 has been found in 8 queries.
# 699 has been found in 3 queries.
# 288 has been found in 10 queries.
# 453 has been found in 9 queries.
# 249 has been found in 4 queries.
# 91 has been found in 10 queries.
# 648 has been found in 8 queries.
# 351 has been found in 9 queries.
# 724 has been found in 9 queries.
# 866 has been found in 8 queries.
# 444 has been found in 10 queries.
# 448 has been found in 10 queries.
# 779 has been found in 7 queries.
# 760 has been found in 10 queries.
# 866 has been found in 8 queries.
# 179 has been found in 10 queries.
# 512 has been found in 9 queries.
# 243 has been found in 9 queries.
# 576 has been found in 6 queries.
# 431 has been found in 10 queries.
# 372 has been found in 9 queries.
# 44 has been found in 9 queries.
# 907 has been found in 10 queries.
# 239 has been found in 9 queries.
# 956 has been found in 10 queries.
# 26 has been found in 10 queries.
# 335 has been found in 9 queries.
# 224 has been found in 9 queries.
# 669 has been found in 10 queries.
# 892 has been found in 4 queries.
# 274 has been found in 2 queries.
# 674 has been found in 9 queries.
# 467 has been found in 10 queries.
# 41 has been found in 10 queries.
# 572 has been found in 9 queries.
# 256 has been found in 6 queries.
# 733 has been found in 10 queries.
# 814 has been found in 7 queries.
# 922 has been found in 10 queries.
# 315 has been found in 10 queries.
# 589 has been found in 7 queries.
# 530 has been found in 9 queries.
# 534 has been found in 10 queries.
# 537 has been found in 8 queries.
# 469 has been found in 9 queries.
# 1160 has been found in 11 queries.
# 497 has been found in 10 queries.
# 598 has been found in 10 queries.
# 988 has been found in 11 queries.
# 309 has been found in 10 queries.
# 111 has been found in 7 queries.
# 179 has been found in 9 queries.
# 814 has been found in 10 queries.
# 1145 has been found in 11 queries.
# 907 has been found in 8 queries.
# 596 has been found in 11 queries.
# 410 has been found in 11 queries.
# 541 has been found in 11 queries.
# 792 has been found in 10 queries.
# 621 has been found in 11 queries.
# 1321 has been found in 11 queries.
# 502 has been found in 6 queries.
# 1101 has been found in 10 queries.
# 914 has been found in 9 queries.
# 578 has been found in 7 queries.
# 1091 has been found in 11 queries.
# 148 has been found in 9 queries.
# 901 has been found in 10 queries.
# 472 has been found in 8 queries.
# 97 has been found in 11 queries.
# 1303 has been found in 10 queries.
# 919 has been found in 10 queries.
# 1431 has been found in 9 queries.
# 767 has been found in 10 queries.
# 1418 has been found in 11 queries.
# 890 has been found in 10 queries.
# 333 has been found in 9 queries.
# 196 has been found in 11 queries.
# 54 has been found in 11 queries.
# 487 has been found in 10 queries.
# 1067 has been found in 8 queries.
# 622 has been found in 10 queries.
# 949 has been found in 5 queries.
# 1109 has been found in 10 queries.
# 387 has been found in 10 queries.
# 1276 has been found in 11 queries.
# 1460 has been found in 10 queries.
# 1303 has been found in 9 queries.
# 36 has been found in 11 queries.
# 648 has been found in 11 queries.
# 380 has been found in 9 queries.
# 1690 has been found in 10 queries.
# 1304 has been found in 10 queries.
# 1548 has been found in 9 queries.
# 1246 has been found in 11 queries.
# 490 has been found in 7 queries.
# 1649 has been found in 10 queries.
# 948 has been found in 8 queries.
# 1056 has been found in 9 queries.
# 1798 has been found in 11 queries.
# 723 has been found in 8 queries.
# 304 has been found in 9 queries.
# 1271 has been found in 8 queries.
# 648 has been found in 9 queries.
# 124 has been found in 10 queries.
# 573 has been found in 10 queries.
# 1482 has been found in 11 queries.
# 1665 has been found in 11 queries.
# 358 has been found in 9 queries.
# 1455 has been found in 11 queries.
# 804 has been found in 11 queries.
# 1152 has been found in 9 queries.
# 1457 has been found in 11 queries.
# 1482 has been found in 11 queries.
# 1833 has been found in 10 queries.
# 1299 has been found in 10 queries.
# 172 has been found in 10 queries.
# 1427 has been found in 11 queries.
# 277 has been found in 11 queries.
# 720 has been found in 11 queries.
# 857 has been found in 11 queries.
# 135 has been found in 9 queries.
# 805 has been found in 10 queries.
# 921 has been found in 11 queries.
# 355 has been found in 11 queries.
# 923 has been found in 11 queries.
# 1794 has been found in 8 queries.
# 314 has been found in 9 queries.
# 1410 has been found in 11 queries.
# 840 has been found in 10 queries.
# 148 has been found in 11 queries.
# 96 has been found in 11 queries.
# 112 has been found in 10 queries.
# 1895 has been found in 11 queries.
# 809 has been found in 11 queries.
# 929 has been found in 9 queries.
# 1691 has been found in 8 queries.
# 1445 has been found in 11 queries.
# 1268 has been found in 11 queries.
# 2134 has been found in 9 queries.
# 1086 has been found in 11 queries.
# 1322 has been found in 7 queries.
# 1352 has been found in 11 queries.
# 1757 has been found in 10 queries.
# 1053 has been found in 10 queries.
# 786 has been found in 10 queries.
# 649 has been found in 9 queries.
# 348 has been found in 12 queries.
# 1844 has been found in 9 queries.
# 372 has been found in 11 queries.
# 2188 has been found in 10 queries.
# 52 has been found in 12 queries.
# 197 has been found in 7 queries.
# 383 has been found in 11 queries.
# 956 has been found in 11 queries.
# 1792 has been found in 10 queries.
# 450 has been found in 11 queries.
# 328 has been found in 10 queries.
# 1268 has been found in 12 queries.
# 1236 has been found in 6 queries.
# 80 has been found in 10 queries.
# 2159 has been found in 9 queries.
# 929 has been found in 11 queries.
# 1536 has been found in 6 queries.
# 1308 has been found in 10 queries.
# 1323 has been found in 11 queries.
# 2456 has been found in 10 queries.
# 1500 has been found in 11 queries.
# 260 has been found in 10 queries.
# 1732 has been found in 11 queries.
# 984 has been found in 8 queries.
# 1874 has been found in 2 queries.
# 1284 has been found in 11 queries.
# 2493 has been found in 12 queries.
# 1850 has been found in 11 queries.
# 153 has been found in 10 queries.
# 2008 has been found in 12 queries.
# 1566 has been found in 12 queries.
# 1613 has been found in 8 queries.
# 280 has been found in 10 queries.
# 1833 has been found in 10 queries.
# 296 has been found in 11 queries.
# 1185 has been found in 12 queries.
# 1531 has been found in 8 queries.
# 1830 has been found in 12 queries.
# 771 has been found in 11 queries.
# 1827 has been found in 9 queries.
# 771 has been found in 11 queries.
# 1600 has been found in 12 queries.
# 551 has been found in 12 queries.
# 601 has been found in 10 queries.
# 492 has been found in 11 queries.
# 1405 has been found in 12 queries.
# 871 has been found in 11 queries.
# 274 has been found in 11 queries.
# 1031 has been found in 12 queries.
# 549 has been found in 12 queries.
# 2322 has been found in 9 queries.
# 2429 has been found in 10 queries.
# 1901 has been found in 12 queries.
# 2660 has been found in 12 queries.
# 2069 has been found in 11 queries.
# 337 has been found in 12 queries.
# 1712 has been found in 12 queries.
# 1627 has been found in 12 queries.
# 1571 has been found in 10 queries.
# 2275 has been found in 8 queries.
# 1192 has been found in 9 queries.
# 2099 has been found in 9 queries.
# 412 has been found in 9 queries.
# 2584 has been found in 11 queries.
# 2488 has been found in 11 queries.
# 2829 has been found in 12 queries.
# 1670 has been found in 11 queries.
# 2874 has been found in 11 queries.
# 1311 has been found in 12 queries.
# 1327 has been found in 12 queries.
# 983 has been found in 6 queries.
# 920 has been found in 12 queries.
# 1762 has been found in 9 queries.
# 237 has been found in 12 queries.
# 1487 has been found in 8 queries.
# 943 has been found in 12 queries.
# 1712 has been found in 10 queries.
# 1250 has been found in 11 queries.
# 1976 has been found in 11 queries.
# 2618 has been found in 11 queries.
# 487 has been found in 11 queries.
# 2050 has been found in 12 queries.
# 605 has been found in 11 queries.
# 1860 has been found in 10 queries.
# 356 has been found in 9 queries.
# 1189 has been found in 11 queries.
# 2610 has been found in 10 queries.
# 567 has been found in 8 queries.
# 2406 has been found in 11 queries.
# 2906 has been found in 11 queries.
# 3138 has been found in 12 queries.
# 647 has been found in 11 queries.
# 1962 has been found in 11 queries.
# 3037 has been found in 11 queries.
# 1212 has been found in 11 queries.
# 1744 has been found in 12 queries.
# 870 has been found in 10 queries.
# 2784 has been found in 11 queries.
# 2800 has been found in 11 queries.
# 2935 has been found in 11 queries.
# 2204 has been found in 12 queries.
# 1552 has been found in 11 queries.
# 2518 has been found in 9 queries.
# 2027 has been found in 12 queries.
# 2082 has been found in 10 queries.
# 1447 has been found in 12 queries.
# 2650 has been found in 10 queries.
# 1676 has been found in 12 queries.
# 1458 has been found in 11 queries.
# 691 has been found in 12 queries.
# 1611 has been found in 9 queries.
# 978 has been found in 12 queries.
# 1959 has been found in 12 queries.
# 1803 has been found in 11 queries.
# 165 has been found in 9 queries.
# 1465 has been found in 9 queries.
# 261 has been found in 10 queries.
# 1940 has been found in 10 queries.
# 2031 has been found in 11 queries.
# 3144 has been found in 12 queries.
# 2051 has been found in 10 queries.
# 1951 has been found in 11 queries.
# 1810 has been found in 11 queries.
# 1297 has been found in 8 queries.
# 891 has been found in 12 queries.
# 2959 has been found in 12 queries.
# 2217 has been found in 11 queries.
# 3383 has been found in 11 queries.
# 365 has been found in 12 queries.
# 2125 has been found in 10 queries.
# 1121 has been found in 12 queries.
# 693 has been found in 11 queries.
# 3122 has been found in 12 queries.
# 2831 has been found in 12 queries.
# 308 has been found in 7 queries.
# 3043 has been found in 9 queries.
# 323 has been found in 11 queries.
# 3261 has been found in 5 queries.
# 148 has been found in 11 queries.
# 1786 has been found in 12 queries.
# 810 has been found in 12 queries.
# 90 has been found in 12 queries.
# 2128 has been found in 12 queries.
# 604 has been found in 11 queries.
# 3045 has been found in 11 queries.
# 3553 has been found in 12 queries.
# 1735 has been found in 12 queries.
# 2287 has been found in 11 queries.
# 3645 has been found in 12 queries.
# 2792 has been found in 10 queries.
# 3604 has been found in 12 queries.
# 3208 has been found in 10 queries.
# 873 has been found in 12 queries.
# 3236 has been found in 12 queries.
# 178 has been found in 11 queries.
# 1887 has been found in 10 queries.
# 2225 has been found in 7 queries.
# 827 has been found in 12 queries.
# 3298 has been found in 12 queries.
# 19 has been found in 12 queries.
# 3862 has been found in 11 queries.
# 3749 has been found in 10 queries.
# 118 has been found in 12 queries.
# 3002 has been found in 10 queries.
# 1676 has been found in 12 queries.
# 2562 has been found in 12 queries.
# 1051 has been found in 12 queries.
# 2425 has been found in 12 queries.
# 1131 has been found in 12 queries.
# 3645 has been found in 11 queries.
# 277 has been found in 12 queries.
# 2571 has been found in 12 queries.
# 1082 has been found in 11 queries.
# 3911 has been found in 12 queries.
# 521 has been found in 12 queries.
# 764 has been found in 8 queries.
# 3136 has been found in 12 queries.
# 813 has been found in 12 queries.
# 2465 has been found in 11 queries.
# 1727 has been found in 12 queries.
# 1809 has been found in 12 queries.
# 295 has been found in 12 queries.
# 2058 has been found in 12 queries.
# 3627 has been found in 12 queries.
# 2246 has been found in 12 queries.
# 206 has been found in 11 queries.
# 3104 has been found in 11 queries.
# 1432 has been found in 9 queries.
# 2204 has been found in 12 queries.
# 263 has been found in 12 queries.
# 74 has been found in 12 queries.
# 2269 has been found in 12 queries.
# 185 has been found in 11 queries.
# 3371 has been found in 11 queries.
# 2438 has been found in 10 queries.
# 3035 has been found in 11 queries.
# 3838 has been found in 12 queries.
# 163 has been found in 7 queries.
# 2793 has been found in 11 queries.
# 3724 has been found in 11 queries.
# 766 has been found in 10 queries.
# 2870 has been found in 8 queries.
# 2980 has been found in 12 queries.
# 2723 has been found in 10 queries.
# 731 has been found in 11 queries.
# 3920 has been found in 12 queries.
# 2651 has been found in 13 queries.
# 1377 has been found in 11 queries.
# 2201 has been found in 11 queries.
# 1975 has been found in 8 queries.
# 2580 has been found in 10 queries.
# 1563 has been found in 12 queries.
# 4046 has been found in 9 queries.
# 4251 has been found in 13 queries.
# 4109 has been found in 12 queries.
# 2371 has been found in 12 queries.
# 1046 has been found in 13 queries.
# 2704 has been found in 12 queries.
# 2593 has been found in 8 queries.
# 2259 has been found in 11 queries.
# 3393 has been found in 11 queries.
# 327 has been found in 12 queries.
# 2638 has been found in 12 queries.
# 62 has been found in 12 queries.
# 614 has been found in 8 queries.
# 4218 has been found in 12 queries.
# 3609 has been found in 13 queries.
# 3295 has been found in 12 queries.
# 780 has been found in 9 queries.
# 1925 has been found in 10 queries.
# 3599 has been found in 12 queries.
# 2825 has been found in 12 queries.
# 137 has been found in 12 queries.
# 121 has been found in 12 queries.
# 565 has been found in 9 queries.
# 2278 has been found in 11 queries.
# 1599 has been found in 12 queries.
# 2579 has been found in 11 queries.
# 3954 has been found in 11 queries.
# 3275 has been found in 9 queries.
# 4305 has been found in 11 queries.
# 3637 has been found in 10 queries.
# 4518 has been found in 12 queries.
# 2818 has been found in 11 queries.
# 2136 has been found in 13 queries.
# 2975 has been found in 12 queries.
# 2700 has been found in 10 queries.
# 2219 has been found in 13 queries.
# 2119 has been found in 12 queries.
# 635 has been found in 13 queries.
# 3595 has been found in 12 queries.
# 1258 has been found in 12 queries.
# 1476 has been found in 12 queries.
# 356 has been found in 12 queries.
# 1099 has been found in 13 queries.
# 190 has been found in 10 queries.
# 4285 has been found in 11 queries.
# 2121 has been found in 10 queries.
# 4157 has been found in 12 queries.
# 876 has been found in 11 queries.
# 1843 has been found in 12 queries.
# 3782 has been found in 13 queries.
# 4805 has been found in 12 queries.
# 3366 has been found in 13 queries.
# 4330 has been found in 11 queries.
# 2847 has been found in 11 queries.
# 4742 has been found in 11 queries.
# 3473 has been found in 11 queries.
# 3505 has been found in 10 queries.
# 3138 has been found in 10 queries.
# 3720 has been found in 12 queries.
# 663 has been found in 7 queries.
# 1565 has been found in 10 queries.
# 4540 has been found in 12 queries.
# 1555 has been found in 13 queries.
# 1198 has been found in 13 queries.
# 4775 has been found in 11 queries.
# 2963 has been found in 12 queries.
# 4249 has been found in 12 queries.
# 4191 has been found in 9 queries.
# 2978 has been found in 11 queries.
# 924 has been found in 13 queries.
# 1487 has been found in 10 queries.
# 2818 has been found in 12 queries.
# 3236 has been found in 12 queries.
# 1024 has been found in 9 queries.
# 73 has been found in 13 queries.
# 1633 has been found in 11 queries.
# 4796 has been found in 11 queries.
# 2865 has been found in 12 queries.
# 927 has been found in 10 queries.
# 4928 has been found in 13 queries.
# 3423 has been found in 11 queries.
# 321 has been found in 11 queries.
# 1633 has been found in 13 queries.
# 4328 has been found in 12 queries.
# 174 has been found in 11 queries.
# 5115 has been found in 12 queries.
# 2904 has been found in 12 queries.
# 1116 has been found in 7 queries.
# 5276 has been found in 12 queries.
# 2422 has been found in 11 queries.
# 1533 has been found in 12 queries.
# 984 has been found in 11 queries.
# 479 has been found in 13 queries.
# 3004 has been found in 13 queries.
# 1376 has been found in 12 queries.
# 2291 has been found in 12 queries.
# 1871 has been found in 9 queries.
# 396 has been found in 13 queries.
# 3796 has been found in 12 queries.
# 1512 has been found in 12 queries.
# 249 has been found in 11 queries.
# 1031 has been found in 13 queries.
# 4843 has been found in 13 queries.
# 4093 has been found in 11 queries.
# 2992 has been found in 13 queries.
# 3075 has been found in 11 queries.
# 1864 has been found in 13 queries.
# 3246 has been found in 13 queries.
# 1179 has been found in 13 queries.
# 1054 has been found in 12 queries.
# 3312 has been found in 10 queries.
# 4698 has been found in 12 queries.
# 3898 has been found in 9 queries.
# 1796 has been found in 13 queries.
# 4510 has been found in 7 queries.
# 1114 has been found in 12 queries.
# 5435 has been found in 12 queries.
# 4331 has been found in 12 queries.
# 1220 has been found in 13 queries.
# 2282 has been found in 12 queries.
# 3300 has been found in 12 queries.
# 3318 has been found in 10 queries.
# 400 has been found in 11 queries.
# 5247 has been found in 12 queries.
# 57 has been found in 12 queries.
# 74 has been found in 12 queries.
# 1019 has been found in 12 queries.
# 812 has been found in 9 queries.
# 5460 has been found in 13 queries.
# 3718 has been found in 11 queries.
# 4160 has been found in 13 queries.
# 851 has been found in 12 queries.
# 1732 has been found in 11 queries.
# 2645 has been found in 12 queries.
# 943 has been found in 12 queries.
# 2013 has been found in 9 queries.
# 4357 has been found in 10 queries.
# 4924 has been found in 13 queries.
# 1343 has been found in 11 queries.
# 5447 has been found in 9 queries.
# 3567 has been found in 12 queries.
# 3702 has been found in 9 queries.
# 672 has been found in 10 queries.
# 2716 has been found in 13 queries.
# 3612 has been found in 9 queries.
# 4247 has been found in 12 queries.
# 3028 has been found in 10 queries.
# 2699 has been found in 13 queries.
# 2510 has been found in 8 queries.
# 866 has been found in 11 queries.
# 5032 has been found in 13 queries.
# 3374 has been found in 9 queries.
# 34 has been found in 9 queries.
# 5488 has been found in 10 queries.
# 4721 has been found in 12 queries.
# 5037 has been found in 12 queries.
# 3609 has been found in 13 queries.
# 278 has been found in 12 queries.
# 4552 has been found in 13 queries.
# 4095 has been found in 12 queries.
# 3394 has been found in 11 queries.
# 4027 has been found in 11 queries.
# 1360 has been found in 11 queries.
# 5771 has been found in 13 queries.
# 2613 has been found in 12 queries.
# 3675 has been found in 11 queries.
# 649 has been found in 10 queries.
# 4809 has been found in 12 queries.
# 836 has been found in 11 queries.
# 3638 has been found in 12 queries.
# 119 has been found in 12 queries.
# 5358 has been found in 13 queries.
# 3909 has been found in 12 queries.
# 4131 has been found in 13 queries.
# 4859 has been found in 6 queries.
# 3376 has been found in 10 queries.
# 2144 has been found in 13 queries.
# 1587 has been found in 13 queries.
# 4968 has been found in 13 queries.
# 594 has been found in 13 queries.
# 166 has been found in 12 queries.
# 1345 has been found in 11 queries.
# 4063 has been found in 11 queries.
# 3073 has been found in 13 queries.
# 1633 has been found in 9 queries.
# 2240 has been found in 12 queries.
# 600 has been found in 13 queries.
# 5170 has been found in 12 queries.
# 5210 has been found in 13 queries.
# 5853 has been found in 12 queries.
# 5037 has been found in 12 queries.
# 1320 has been found in 10 queries.
# 2351 has been found in 11 queries.
# 3699 has been found in 12 queries.
# 6024 has been found in 11 queries.
# 792 has been found in 13 queries.
# 293 has been found in 13 queries.
# 3877 has been found in 11 queries.
# 5959 has been found in 12 queries.
# 1134 has been found in 12 queries.
# 3255 has been found in 10 queries.
# 1748 has been found in 13 queries.
# 3071 has been found in 13 queries.
# 1224 has been found in 8 queries.
# 1388 has been found in 13 queries.
# 5697 has been found in 12 queries.
# 5872 has been found in 12 queries.
# 6123 has been found in 10 queries.
# 1047 has been found in 12 queries.
# 6013 has been found in 12 queries.
# 4401 has been found in 12 queries.
# 315 has been found in 13 queries.
# 2589 has been found in 12 queries.
# 4183 has been found in 11 queries.
# 3329 has been found in 13 queries.
# 923 has been found in 12 queries.
# 4479 has been found in 9 queries.
# 4581 has been found in 12 queries.
# 4254 has been found in 13 queries.
# 773 has been found in 12 queries.
# 5013 has been found in 9 queries.
# 1510 has been found in 12 queries.
# 3009 has been found in 13 queries.
# 5029 has been found in 11 queries.
# 5121 has been found in 13 queries.
# 1071 has been found in 11 queries.
# 926 has been found in 13 queries.
# 5792 has been found in 13 queries.
# 185 has been found in 11 queries.
# 2563 has been found in 7 queries.
# 5633 has been found in 11 queries.
# 4065 has been found in 12 queries.
# 5698 has been found in 13 queries.
# 2096 has been found in 12 queries.
# 2798 has been found in 8 queries.
# 4067 has been found in 9 queries.
# 6399 has been found in 13 queries.
# 4226 has been found in 12 queries.
# 2402 has been found in 9 queries.
# 587 has been found in 12 queries.
# 4101 has been found in 13 queries.
# 2853 has been found in 9 queries.
# 829 has been found in 12 queries.
# 4074 has been found in 13 queries.
# 2435 has been found in 10 queries.
# 2641 has been found in 9 queries.
# 189 has been found in 12 queries.
# 5138 has been found in 12 queries.
# 3017 has been found in 4 queries.
# 5737 has been found in 12 queries.
# 4255 has been found in 12 queries.
# 3414 has been found in 13 queries.
# 5876 has been found in 13 queries.
# 4495 has been found in 11 queries.
# 2655 has been found in 11 queries.
# 6856 has been found in 12 queries.
# 3559 has been found in 11 queries.
# 1791 has been found in 13 queries.
# 1300 has been found in 11 queries.
# 4308 has been found in 11 queries.
# 685 has been found in 11 queries.
# 6645 has been found in 11 queries.
# 4832 has been found in 12 queries.
# 2206 has been found in 10 queries.
# 4093 has been found in 10 queries.
# 3061 has been found in 4 queries.
# 6202 has been found in 13 queries.
# 5599 has been found in 13 queries.
# 4319 has been found in 12 queries.
# 5020 has been found in 13 queries.
# 2305 has been found in 12 queries.
# 2127 has been found in 12 queries.
# 143 has been found in 13 queries.
# 1992 has been found in 13 queries.
# 4789 has been found in 10 queries.
# 4698 has been found in 13 queries.
# 1405 has been found in 13 queries.
# 4209 has been found in 13 queries.
# 2230 has been found in 11 queries.
# 157 has been found in 11 queries.
# 6969 has been found in 13 queries.
# 5891 has been found in 9 queries.
# 5187 has been found in 13 queries.
# 1617 has been found in 12 queries.
# 4352 has been found in 12 queries.
# 803 has been found in 11 queries.
# 115 has been found in 11 queries.
# 1643 has been found in 12 queries.
# 5287 has been found in 9 queries.
# 5971 has been found in 13 queries.
# 4922 has been found in 12 queries.
# 124 has been found in 11 queries.
# 5296 has been found in 12 queries.
# 4628 has been found in 11 queries.
# 1821 has been found in 13 queries.
# 1843 has been found in 12 queries.
# 2812 has been found in 12 queries.
# 3416 has been found in 10 queries.
# 4365 has been found in 13 queries.
# 886 has been found in 13 queries.
# 4695 has been found in 9 queries.
# 1642 has been found in 11 queries.
# 2793 has been found in 12 queries.
# 359 has been found in 13 queries.
# 4705 has been found in 13 queries.
# 5487 has been found in 11 queries.
# 2869 has been found in 13 queries.
# 2820 has been found in 13 queries.
# 1835 has been found in 13 queries.
# 1971 has been found in 13 queries.
# 2813 has been found in 13 queries.
# 6845 has been found in 10 queries.
# 7103 has been found in 12 queries.
# 4909 has been found in 13 queries.
# 2138 has been found in 12 queries.
# 1769 has been found in 13 queries.
# 6974 has been found in 11 queries.
# 1542 has been found in 6 queries.
# 5871 has been found in 13 queries.
# 2487 has been found in 13 queries.
# 504 has been found in 12 queries.
# 365 has been found in 11 queries.
# 4123 has been found in 12 queries.
# 5818 has been found in 12 queries.
# 2590 has been found in 12 queries.
# 1648 has been found in 13 queries.
# 2421 has been found in 11 queries.
# 5324 has been found in 13 queries.
# 4407 has been found in 13 queries.
# 5404 has been found in 10 queries.
# 956 has been found in 12 queries.
# 7349 has been found in 13 queries.
# 1850 has been found in 13 queries.
# 2561 has been found in 13 queries.
# 6885 has been found in 13 queries.
# 4389 has been found in 13 queries.
# 1091 has been found in 12 queries.
# 2573 has been found in 9 queries.
# 6915 has been found in 12 queries.
# 6826 has been found in 13 queries.
# 1002 has been found in 12 queries.
# 4822 has been found in 12 queries.
# 1499 has been found in 13 queries.
# 4809 has been found in 11 queries.
# 3449 has been found in 13 queries.
# 6488 has been found in 8 queries.
# 6868 has been found in 13 queries.
# 5393 has been found in 12 queries.
# 6242 has been found in 11 queries.
# 3012 has been found in 12 queries.
# 3734 has been found in 13 queries.
# 6969 has been found in 13 queries.
# 6608 has been found in 13 queries.
# 3564 has been found in 12 queries.
# 1581 has been found in 12 queries.
# 5264 has been found in 13 queries.
# 3378 has been found in 13 queries.
# 2295 has been found in 9 queries.
# 4408 has been found in 11 queries.
# 2379 has been found in 12 queries.
# 1893 has been found in 11 queries.
# 5203 has been found in 12 queries.
# 1861 has been found in 13 queries.
# 1836 has been found in 12 queries.
# 6502 has been found in 11 queries.
# 6186 has been found in 7 queries.
# 7011 has been found in 13 queries.
# 882 has been found in 13 queries.
# 7442 has been found in 13 queries.
# 2937 has been found in 13 queries.
# 1520 has been found in 13 queries.
# 80 has been found in 12 queries.
# 7038 has been found in 9 queries.
# 7072 has been found in 12 queries.
# 1172 has been found in 13 queries.
# 480 has been found in 12 queries.
# 1053 has been found in 12 queries.
# 7218 has been found in 11 queries.
# 1533 has been found in 13 queries.
# 4335 has been found in 11 queries.
# 4900 has been found in 13 queries.
# 2 has been found in 12 queries.
# 5096 has been found in 13 queries.
# 7347 has been found in 13 queries.
# 1590 has been found in 12 queries.
# 4183 has been found in 11 queries.
# 1153 has been found in 13 queries.
# 2945 has been found in 13 queries.
# 3424 has been found in 12 queries.
# 6052 has been found in 13 queries.
# 1021 has been found in 13 queries.
# 437 has been found in 13 queries.
# 6459 has been found in 13 queries.
# 6685 has been found in 10 queries.
# 7485 has been found in 12 queries.
# 55 has been found in 13 queries.
# 4961 has been found in 13 queries.
# 7009 has been found in 12 queries.
# 3878 has been found in 10 queries.
# 3025 has been found in 10 queries.
# 1894 has been found in 12 queries.
# 2027 has been found in 13 queries.
# 2815 has been found in 11 queries.
# 4587 has been found in 11 queries.
# 3052 has been found in 12 queries.
# 2984 has been found in 8 queries.
# 3290 has been found in 12 queries.
# 3323 has been found in 13 queries.
# 6132 has been found in 10 queries.
# 2233 has been found in 12 queries.
# 7724 has been found in 13 queries.
# 1832 has been found in 10 queries.
# 751 has been found in 12 queries.
# 3375 has been found in 10 queries.
# 1997 has been found in 12 queries.
# 6817 has been found in 11 queries.
# 6876 has been found in 13 queries.
# 6293 has been found in 13 queries.
# 594 has been found in 13 queries.
# 8291 has been found in 11 queries.
# 1703 has been found in 13 queries.
# 3425 has been found in 7 queries.
# 6614 has been found in 13 queries.
# 2205 has been found in 12 queries.
# 4100 has been found in 13 queries.
# 5356 has been found in 14 queries.
# 5971 has been found in 12 queries.
# 8186 has been found in 12 queries.
# 3377 has been found in 12 queries.
# 4339 has been found in 13 queries.
# 5300 has been found in 6 queries.
# 2908 has been found in 11 queries.
# 399 has been found in 13 queries.
# 3341 has been found in 11 queries.
# 1053 has been found in 8 queries.
# 1651 has been found in 11 queries.
# 6307 has been found in 11 queries.
# 6650 has been found in 9 queries.
# 4889 has been found in 13 queries.
# 7984 has been found in 12 queries.
# 174 has been found in 13 queries.
# 1784 has been found in 13 queries.
# 788 has been found in 14 queries.
# 5934 has been found in 12 queries.
# 7170 has been found in 11 queries.
# 4913 has been found in 14 queries.
# 1366 has been found in 13 queries.
# 121 has been found in 9 queries.
# 7168 has been found in 10 queries.
# 7166 has been found in 12 queries.
# 4298 has been found in 13 queries.
# 921 has been found in 13 queries.
# 5038 has been found in 14 queries.
# 4562 has been found in 13 queries.
# 6481 has been found in 9 queries.
# 7701 has been found in 13 queries.
# 7435 has been found in 12 queries.
# 3023 has been found in 12 queries.
# 7774 has been found in 12 queries.
# 133 has been found in 12 queries.
# 4958 has been found in 13 queries.
# 1231 has been found in 12 queries.
# 6352 has been found in 10 queries.
# 1804 has been found in 13 queries.
# 8342 has been found in 11 queries.
# 7428 has been found in 11 queries.
# 1241 has been found in 11 queries.
# 5057 has been found in 13 queries.
# 1209 has been found in 13 queries.
# 5698 has been found in 11 queries.
# 2375 has been found in 11 queries.
# 3379 has been found in 11 queries.
# 1135 has been found in 13 queries.
# 7102 has been found in 13 queries.
# 2117 has been found in 11 queries.
# 2562 has been found in 11 queries.
# 7875 has been found in 11 queries.
# 5303 has been found in 11 queries.
# 3252 has been found in 13 queries.
# 8526 has been found in 13 queries.
# 2459 has been found in 14 queries.
# 7474 has been found in 4 queries.
# 1337 has been found in 10 queries.
# 7138 has been found in 12 queries.
# 4753 has been found in 12 queries.
# 7426 has been found in 12 queries.
# 7378 has been found in 13 queries.
# 874 has been found in 13 queries.
# 2843 has been found in 12 queries.
# 706 has been found in 14 queries.
# 8231 has been found in 13 queries.
# 5055 has been found in 14 queries.
# 1895 has been found in 13 queries.
# 730 has been found in 11 queries.
# 2368 has been found in 14 queries.
# 1724 has been found in 9 queries.
# 4732 has been found in 12 queries.
# 8976 has been found in 9 queries.
# 907 has been found in 10 queries.
# 3903 has been found in 11 queries.
# 7961 has been found in 11 queries.
# 2102 has been found in 12 queries.
# 8481 has been found in 13 queries.
# 1076 has been found in 11 queries.
# 7611 has been found in 13 queries.
# 2748 has been found in 13 queries.
# 3471 has been found in 13 queries.
# 66 has been found in 12 queries.
# 1665 has been found in 12 queries.
# 2570 has been found in 12 queries.
# 4261 has been found in 11 queries.
# 914 has been found in 12 queries.
# 2081 has been found in 11 queries.
# 8308 has been found in 12 queries.
# 7337 has been found in 13 queries.
# 6104 has been found in 12 queries.
# 8492 has been found in 13 queries.
# 21 has been found in 13 queries.
# 2637 has been found in 11 queries.
# 1300 has been found in 14 queries.
# 4389 has been found in 13 queries.
# 8448 has been found in 13 queries.
# 7736 has been found in 13 queries.
# 868 has been found in 13 queries.
# 362 has been found in 13 queries.
# 9366 has been found in 12 queries.
# 3493 has been found in 13 queries.
# 7628 has been found in 11 queries.
# 8332 has been found in 13 queries.
# 6561 has been found in 14 queries.
# 8661 has been found in 13 queries.
# 250 has been found in 11 queries.
# 4018 has been found in 11 queries.
# 3158 has been found in 13 queries.
# 2085 has been found in 12 queries.
# 1990 has been found in 12 queries.
# 993 has been found in 10 queries.
# 2415 has been found in 13 queries.
# 957 has been found in 13 queries.
# 9396 has been found in 9 queries.
# 9087 has been found in 12 queries.
# 8645 has been found in 11 queries.
# 2612 has been found in 13 queries.
# 2097 has been found in 14 queries.
# 3908 has been found in 13 queries.
# 920 has been found in 12 queries.
# 4178 has been found in 13 queries.
# 8052 has been found in 13 queries.
# 1110 has been found in 10 queries.
# 5262 has been found in 11 queries.
# 177 has been found in 11 queries.
# 2072 has been found in 13 queries.
# 4066 has been found in 14 queries.
# 6264 has been found in 13 queries.
# 8658 has been found in 12 queries.
# 5561 has been found in 14 queries.
# 2247 has been found in 12 queries.
# []

# %% [markdown]
# # Problem #2.6
# Together, let's see how the performance of binary and linear search change when the order of items in the list is random using the random.sample(...) function. We will do this in 3 steps:
#
# * Rewrite the linear_search function so that the list is randomly ordered.
# * Rewrite the binary_search function so that the list is randomly ordered.
# * Graph the average number of queries for both search algorithms.

# %% [markdown]
# # Problem 2.6.1
#
# ---
#
#
# Rewrite the linear_search function so that the list is randomly ordered

# %%
def linear_search(n):

  number_trials = 10
  worst_query = 0
  list_items = random.sample(range(n), n)

  for i in range(number_trials):

    marked_item = random.choice(list_items)
    number_queries = 0
    for item in list_items:

      number_queries = number_queries + 1

      if item == marked_item:
        #print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break

    worst_query = max(worst_query, number_queries)

  return worst_query

# %% [markdown]
# # Problem #2.6.2
#
# ---
#
#
# Rewrite the binary_search function so that the list is randomly ordered.

# %%
def binary_search(n):

  number_trials = 10
  worst_query = 0
  list_items = random.sample(range(n), n)

  for i in range(number_trials):

    marked_item = random.choice(list_items)

    left = 0
    right = len(list_items) - 1

    number_queries = 0
    for item in list_items:

      number_queries = number_queries + 1

      middle = int((left + right)/2)
      if list_items[middle] > marked_item:
        right = middle
      elif list_items[middle] < marked_item:
        left = middle
      else:
        #print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break

    worst_query = max(worst_query, number_queries)

  return worst_query

# %% [markdown]
# # Problem #2.6.3
#
# ---
#
#
# Graph the average number of queries for both search algorithms.

# %%
linear_queries = []
binary_queries = []
ns = range(100, 10000, 100)
for n in ns:
  linear_queries += [linear_search(n)]
  binary_queries += [binary_search(n)]

plt.scatter(ns, linear_queries, label = "linear")
plt.scatter(ns, binary_queries, label = "binary")

plt.xlabel("n")
plt.ylabel("Worst Number of Queries")
plt.title("Linear and Binary Search Worst Number of Queries with Increasing List Size")
plt.legend()

plt.plot()
# Out:
# []
