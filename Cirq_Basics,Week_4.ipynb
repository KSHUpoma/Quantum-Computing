# %% [markdown]
# # Week 4: Introduction to Quantum Circuits

# %%
import warnings
warnings.filterwarnings("ignore")


try:
    import cirq
except ImportError:
    print("installing cirq...")
    # !pip install cirq --quiet
    import cirq
    print("installed cirq.")


import matplotlib.pyplot as plt


print("Libraries Imported Successfully!")
# Out:
# installing cirq...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 kB 1.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 25.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.7/532.7 kB 32.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.5/60.5 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.3/69.3 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 596.5/596.5 kB 36.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.9/202.9 kB 15.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 83.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 68.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 65.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 58.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.1/739.1 kB 39.0 MB/s eta 0:00:00
#   Building wheel for rpcq (setup.py) ... done
# installed cirq.
# Libraries Imported Successfully!

# %% [markdown]
# # Part 1: Creating Quantum Circuits

# %% [markdown]
# # **Problem #1.1**

# %%
# Step 1: Define qubit(s)
qubit = cirq.NamedQubit('q0')

# Step 2: Define a quantum circuit
circuit = cirq.Circuit()

# Step 3: Append gates and measurements to the quantum circuit
circuit.append(cirq.X(qubit))


print(circuit)
# Out:
# q0: ───X───

# %% [markdown]
# # **Problem #1.2**

# %%
#Now, let's add a measurement to this same circuit object and print the resulting circuit.

# %%
circuit.append(cirq.measure(qubit))

# %%
circuit
# Out:
# q0: ───X───M───

# %%
circuit.append(cirq.measure(qubit))

print(circuit)
# Out:
# q0: ───X───M───M───

# %% [markdown]
# # Problem #1.3

# %%
#Append an H gate to this same circuit object and print the resulting circuit.

# %%
circuit.append(cirq.H(qubit))

print(circuit)
# Out:
# q0: ───X───M───M───H───

# %% [markdown]
# # Problems #1.4-1.6

# %%
#Create a new qubit named "Q-Boi" and a new circuit object. Then apply an H gate and a measurement to this new circuit and print the resulting circuit out.

# %%
# Step 1: Define qubit(s)
qubit = cirq.NamedQubit('Q-Boi')

# Step 2: Define a quantum circuit
circuit = cirq.Circuit()

# Step 3: Append gates and measurements to the quantum circuit
circuit.append(cirq.H(qubit))
circuit.append(cirq.measure(qubit))

print(circuit)
# Out:
# Q-Boi: ───H───M───

# %% [markdown]
# # Problem #1.5

# %%
#Create a new qubit named "my qubit" and a new circuit object. Then apply a measurement and an H gate (the reverse order from the problem above) to this new circuit and print the resulting circuit out.

# %%
# Step 1: Define qubit(s)
qubit = cirq.NamedQubit('my qubit')

# Step 2: Define a quantum circuit
circuit = cirq.Circuit()

# Step 3: Append gates and measurements to the quantum circuit
circuit.append(cirq.measure(qubit))
circuit.append(cirq.H(qubit))


print(circuit)
# Out:
# my qubit: ───M───H───

# %% [markdown]
# # Problem #1.6
#
# ---
#
# Create a new qubit named "my qubit" and a new circuit object. Then apply 2 measurements to this new circuit and print the resulting circuit out.

# %%
# Step 1: Define qubit(s)
qubit = cirq.NamedQubit('my qubit')

# Step 2: Define a quantum circuit
circuit = cirq.Circuit()

# Step 3: Append gates and measurements to the quantum circuit
circuit.append(cirq.measure(qubit))
circuit.append(cirq.measure(qubit))


print(circuit)
# Out:
# my qubit: ───M───M───

# %% [markdown]
# # Problem #1.7
# Let's run the code below to:
#
# 1.Create a qubit named "Adam".
#
# 2.Create a new circuit object.
#
# 3.Apply 4 X gates and a measurement.
#
# 4.Print the circuit out.

# %%
# Step 1: Define qubit(s)
qubit = cirq.NamedQubit('Adam')

# Step 2: Define a quantum circuit
circuit = cirq.Circuit()

# Step 3: Append gates and measurements to the quantum circuit
circuit.append(cirq.X(qubit))
circuit.append(cirq.X(qubit))
circuit.append(cirq.X(qubit))
circuit.append(cirq.X(qubit))



circuit.append(cirq.measure(qubit))

print(circuit)
# Out:
# Adam: ───X───X───X───X───M───

# %% [markdown]
# # Problem #1.8
#
# ---
# Let's:
#
# 1.Create a qubit with your own name (ex: "Adam").
#
# 2.Create a new circuit object.
#
# 3.Apply 2 X gates, 1 H gate, and a measurement.
#
# Print the circuit out.

# %%
# Step 1: Define qubit(s)
qubit = cirq.NamedQubit('Adam')

# Step 2: Define a quantum circuit
circuit = cirq.Circuit()

# Step 3: Append gates and measurements to the quantum circuit
circuit.append(cirq.X(qubit))
circuit.append(cirq.X(qubit))

circuit.append(cirq.H(qubit))

circuit.append(cirq.measure(qubit))

print(circuit)
# Out:
# Adam: ───X───X───H───M───

# %% [markdown]
# # Problem #1.9
# Now, create a circuit that applies the following gates and measurements on a single qubit with the name 'q0':
#
# 4 X's
#
# 4 H's
#
# Measurement

# %%
# Step 1: Define qubit(s)
qubit = cirq.NamedQubit('q0')

# Step 2: Define a quantum circuit
circuit = cirq.Circuit()

# Step 3: Append gates and measurements to the quantum circuit
circuit.append(cirq.X(qubit))
circuit.append(cirq.X(qubit))
circuit.append(cirq.X(qubit))
circuit.append(cirq.X(qubit))

circuit.append(cirq.H(qubit))
circuit.append(cirq.H(qubit))
circuit.append(cirq.H(qubit))
circuit.append(cirq.H(qubit))

circuit.append(cirq.measure(qubit))


print(circuit)
# Out:
# q0: ───X───X───X───X───H───H───H───H───M───

# %% [markdown]
# # Problem #1.10
# Now, create a circuit that applies the following gates and measurements on a single qubit with the name 'q0':
#
# X
#
# H
#
# Measurement
#
# H
#
# Measurement

# %%
# Step 1: Define qubit(s)
qubit = cirq.NamedQubit('q0')

# Step 2: Define a quantum circuit
circuit = cirq.Circuit()

# Step 3: Append gates and measurements to the quantum circuit
circuit.append(cirq.X(qubit))
circuit.append(cirq.H(qubit))
circuit.append(cirq.measure(qubit))
circuit.append(cirq.H(qubit))
circuit.append(cirq.measure(qubit))


print(circuit)
# Out:
# q0: ───X───H───M───H───M───

# %%
# Step 1: Define qubit(s)
qubit = cirq.NamedQubit('q0')

# Step 2: Define a quantum circuit
circuit = cirq.Circuit()

# Step 3: Append gates and measurements to the quantum circuit
circuit.append(cirq.X(qubit))
circuit.append(cirq.H(qubit))
circuit.append(cirq.measure(qubit))
circuit.append(cirq.H(qubit))
circuit.append(cirq.measure(qubit))


print(circuit)
# Out:
# q0: ───X───H───M───H───M───

# %% [markdown]
# # Part 2: Simulating Quantum Circuits
#
# ---
#
#
# *   Simulate our circuits.
#
# *   Visualize the measurement results.

# %% [markdown]
# # Problem #2.1
# To start, let's create a circuit that applies an X gate to a qubit and measures it. Then, we will run the provided code to simulate these measurements.

# %%
#step1: make the qubit
qubit = cirq.NamedQubit("q0")

#Step2: make the empty circuit
circuit = cirq.Circuit()

#Step3: add the x-gate operated qubit to the circuit
circuit.append(cirq.H(qubit))
circuit.append(cirq.Z(qubit))
circuit.append(cirq.M(qubit))
circuit
# Out:
# q0: ───H───Z───M───

# %%
# Step 4: Run the circuit
sim = cirq.Simulator()
result = sim.run(circuit, repetitions = 10**6)

print(result)
# Out:
# q0=...

# %%
# Step 1: Define qubit(s)
qubit = cirq.NamedQubit('q0')

# Step 2: Define a quantum circuit
circuit = cirq.Circuit()

# Step 3: Append gates and measurements to the quantum circuit
circuit.append(cirq.X(qubit))
circuit.append(cirq.measure(qubit))


print(circuit)
# Out:
# q0: ───X───M───

# %%
# Step 4: Run the circuit
sim = cirq.Simulator()
result = sim.run(circuit, repetitions = 1)

print(result)
# Out:
# q0=1

# %% [markdown]
# # Problem #2.2
#
# ---
#
# Let's run the same circuit again and print the results, but with 10 repetitions.

# %%
# Step 4: Run the circuit
sim = cirq.Simulator()
result = sim.run(circuit, repetitions = 10)

print(result)
# Out:
# q0=1111111111

# %% [markdown]
# # Problem #2.3
#
# ---
#
# Now, create a circuit with an H gate and a measurement applied to a qubit with a name of your choice. Then simulate it with 100 repetitions and print the result.

# %%
# Step 1: Define qubit(s)
qubit = cirq.NamedQubit('q0')

# Step 2: Define a quantum circuit
circuit = cirq.Circuit()

# Step 3: Append gates and measurements to the quantum circuit
circuit.append(cirq.H(qubit))
circuit.append(cirq.measure(qubit))


print(circuit)
# Out:
# q0: ───H───M───

# %%
# Step 4: Run the circuit
sim = cirq.Simulator()
result = sim.run(circuit, repetitions = 100)

print(result)
# Out:
# q0=1000000010100000111100110001010010111011110011000100100100111100000001000100101001011010011101010100

# %% [markdown]
# # Problem #2.4
#
# ---
#
#
# Let's visualize the results from the last circuit using a histogram.

# %%
hist = cirq.plot_state_histogram(result, plt.subplot(), title = 'Qubit States', xlabel = 'States', ylabel = 'Occurrences')
plt.show()

# %% [markdown]
# # Problem #2.5
#
# ---
#
#
#
# *   Now, put everything together by doing the following:
#
# * Create a circuit that applies an X gate and a measurement to a qubit.
#
# * Run this circuit 500 times.
# * Visualize the measurement results with a histogram.
# *   List item

# %%
# Step 1: Define qubit(s)
qubit = cirq.NamedQubit('q0')

# Step 2: Define a quantum circuit
circuit = cirq.Circuit()

# Step 3: Append gates and measurements to the quantum circuit
circuit.append(cirq.X(qubit))
circuit.append(cirq.measure(qubit))


print(circuit)
# Out:
# q0: ───X───M───

# %%
# Step 4: Run the circuit
sim = cirq.Simulator()
result = sim.run(circuit, repetitions = 500)

print(result)
# Out:
# q0=...

# %%
hist = cirq.plot_state_histogram(result, plt.subplot(), title = 'Qubit States', xlabel = 'States', ylabel = 'Occurrences')
plt.show()

# %% [markdown]
# # Problem #2.6
#
# ---
#
#
# *   Write code that does the following:
#
# * Create a circuit that applies an X gate, H gate, and a measurement to a single qubit.
# * Run this circuit 500 times.
# * Visualize the measurement results with a histogram.
# *   List item

# %%
# Step 1: Define qubit(s)
qubit = cirq.NamedQubit('q0')

# Step 2: Define a quantum circuit
circuit = cirq.Circuit()

# Step 3: Append gates and measurements to the quantum circuit
circuit.append(cirq.X(qubit))
circuit.append(cirq.H(qubit))
circuit.append(cirq.H(qubit))
circuit.append(cirq.measure(qubit))


print(circuit)
# Out:
# q0: ───X───H───H───M───

# %%
# Step 4: Run the circuit
sim = cirq.Simulator()
result = sim.run(circuit, repetitions = 500)

print(result)
# Out:
# q0=...

# %%
hist = cirq.plot_state_histogram(result, plt.subplot(), title = 'Qubit States', xlabel = 'States', ylabel = 'Occurrences')
plt.show()

# %% [markdown]
# # Part 3: Quantum Mechanics of Qubits
#
# ---
# In this section, we will explore superposition, interference, and measurement for qubits.

# %% [markdown]
# # Problem #3.1
# Let's start by creating a circuit that demonstrates superposition using

# %%
# Step 1: Define qubit(s)
qubit = cirq.NamedQubit('q0')

# Step 2: Define a quantum circuit
circuit = cirq.Circuit()

# Step 3: Append gates and measurements to the quantum circuit
circuit.append(cirq.H(qubit))
circuit.append(cirq.measure(qubit))

print(circuit)
# Out:
# q0: ───H───M───

# %%
# Step 4: Running the circuit
sim = cirq.Simulator()
result = sim.run(circuit, repetitions = 1000)

hist = cirq.plot_state_histogram(result, plt.subplot(), title = 'Qubit States', xlabel = 'States', ylabel = 'Occurrences')
plt.show()

# %% [markdown]
# # Problem #3.2
#
# ---
#
#
# Now, add to the circuit below to see the results of interference when compared to the circuit above. In particular, append a second gate before measurement so that the likelihood of measuring 0 vs. 1 changes.

# %%
# Step 1: Define qubit(s)
qubit = cirq.NamedQubit('q0')

# Step 2: Define a quantum circuit
circuit = cirq.Circuit()

# Step 3: Append gates and measurements to the quantum circuit
circuit.append(cirq.H(qubit))
circuit.append(cirq.H(qubit))
circuit.append(cirq.measure(qubit))

print(circuit)
# Out:
# q0: ───H───H───M───

# %%
# Step 4: Running the circuit
sim = cirq.Simulator()
result = sim.run(circuit, repetitions = 100)

hist = cirq.plot_state_histogram(result, plt.subplot(), title = 'Qubit States', xlabel = 'States', ylabel = 'Occurrences')
plt.show()

# %% [markdown]
# # Reflection
#
# ---
#
#
# How have the above circuits demonstrated superposition and interference?

# %% [markdown]
# # Solution
# In the first circuit, we created a superposition using the H gate. Although the exact nature of this superposition is not as clear as an electron going through both slits in the double slit experiment, the results look the same.
#
#
# In the second circuit, we were able to destructively interfere the 1 state and constructively interfere the 0 state by applying a second H gate. Again, what is happening physically to accomplish this depends on the physical system being used, but the results are the same regardless.

# %% [markdown]
# # Problem #3.3
#
# * Lastly, let's show the destructive effect of quantum measurement. Specifically, we will simulate and visualize the histogram of results for three very similar circuits:
#
# * H gate, H gate, measurement. NOTE: You have likely already created this circuit or one similar to it above.
#
# * H gate, measurement, H gate, measurement. NOTE: We have provided this code for you so you can see the implementation details noted below.
#
# * H gate, measurement, measurement.
#
# #NOTE: There are two main adjustments we have made to account for multiple measurements in the same circuit:
#
# * To distinguish the results between the measurements on the same qubit, we will label each measurement with a unique "key" of our choosing by using cirq.measure(qubit, key = '...'). Cirq will actually throw an error if we don't!
#
# * To make the histogram as meaningful as possible, we will specify our own labels for each outcome instead of cirq's default 0, 1, 2, 3,...

# %%
# Step 1: Define qubit(s)
qubit = cirq.NamedQubit('q0')

# Step 2: Define a quantum circuit
circuit = cirq.Circuit()

# Step 3: Append gates and measurements to the quantum circuit
circuit.append(cirq.H(qubit))
circuit.append(cirq.measure(qubit, key = '1'))
circuit.append(cirq.H(qubit))
circuit.append(cirq.measure(qubit, key = '2'))

sim = cirq.Simulator()
result = sim.run(circuit, repetitions = 100)

hist = cirq.plot_state_histogram(result, plt.subplot(), title = 'Qubit States', xlabel = 'States', ylabel = 'Occurrences', tick_label = ['0 then 0', '1 then 0', '0 then 1', '1 then 1'])

plt.show()

# %%
# Step 1: Define qubit(s)
qubit = cirq.NamedQubit('q0')

# Step 2: Define a quantum circuit
circuit = cirq.Circuit()

# Step 3: Append gates and measurements to the quantum circuit
circuit.append(cirq.H(qubit))
circuit.append(cirq.H(qubit))
circuit.append(cirq.measure(qubit))

sim = cirq.Simulator()
result = sim.run(circuit, repetitions = 100)

hist = cirq.plot_state_histogram(result, plt.subplot(), title = 'Qubit States', xlabel = 'States', ylabel = 'Occurrences')
plt.show()

# %%
# Step 1: Define qubit(s)
qubit = cirq.NamedQubit('q0')

# Step 2: Define a quantum circuit
circuit = cirq.Circuit()

# Step 3: Append gates and measurements to the quantum circuit
circuit.append(cirq.H(qubit))
circuit.append(cirq.H(qubit))
circuit.append(cirq.measure(qubit))

sim = cirq.Simulator()
result = sim.run(circuit, repetitions = 100)

hist = cirq.plot_state_histogram(result, plt.subplot(), title = 'Qubit States', xlabel = 'States', ylabel = 'Occurrences')
plt.show()

# %%
# Step 1: Define qubit(s)
qubit = cirq.NamedQubit('q0')

# Step 2: Define a quantum circuit
circuit = cirq.Circuit()

# Step 3: Append gates and measurements to the quantum circuit
circuit.append(cirq.H(qubit))
circuit.append(cirq.measure(qubit, key = '1'))
circuit.append(cirq.H(qubit))
circuit.append(cirq.measure(qubit, key = '2'))

sim = cirq.Simulator()
result = sim.run(circuit, repetitions = 100)

hist = cirq.plot_state_histogram(result, plt.subplot(), title = 'Qubit States', xlabel = 'States', ylabel = 'Occurrences', tick_label = ['0 then 0', '1 then 0', '0 then 1', '1 then 1'])

plt.show()

# %%
# Step 1: Define qubit(s)
qubit = cirq.NamedQubit('q0')

# Step 2: Define a quantum circuit
circuit = cirq.Circuit()

# Step 3: Append gates and measurements to the quantum circuit
circuit.append(cirq.H(qubit))
circuit.append(cirq.measure(qubit, key = '1'))
circuit.append(cirq.measure(qubit, key = '2'))

sim = cirq.Simulator()
result = sim.run(circuit, repetitions = 100)

hist = cirq.plot_state_histogram(result, plt.subplot(), title = 'Qubit States', xlabel = 'States', ylabel = 'Occurrences', tick_label = ['0 then 0', '1 then 0', '0 then 1', '1 then 1'])
plt.show()
